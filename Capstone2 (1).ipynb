# %% [markdown]
# ### Functions

# %%
pip install numpy pandas scikit-learn torch torchvision torchaudio transformers nltk openai tqdm matplotlib seaborn
# Out:
# Requirement already satisfied: numpy in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (1.26.4)
# Requirement already satisfied: pandas in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (2.2.3)
# Requirement already satisfied: scikit-learn in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (1.6.1)
# Requirement already satisfied: torch in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (0.20.1+cu121)
# Requirement already satisfied: torchaudio in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (2.5.1+cu121)
# Requirement already satisfied: transformers in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (4.51.3)
# Requirement already satisfied: nltk in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (3.9.1)
# Requirement already satisfied: openai in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (1.81.0)
# Requirement already satisfied: tqdm in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (4.67.1)
# Requirement already satisfied: matplotlib in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (3.10.1)
# Requirement already satisfied: seaborn in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: filelock in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torchvision) (11.0.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from transformers) (0.30.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: click in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from nltk) (8.2.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from openai) (2.11.4)
# Requirement already satisfied: sniffio in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: colorama in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: idna>=2.8 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers) (2.4.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score
import os
import numpy as np
import pandas as pd
import torch
from transformers import BertTokenizer, BertModel
import openai
from torch import nn

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler, TensorDataset
from transformers import BertTokenizer, BertForSequenceClassification
from torch.nn.utils import clip_grad_norm_
import torch.nn as nn

# %%
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

def preprocess_text(text):
    return str(text).replace('&gt', '').replace('\n', ' ').strip().lower()

class BertBinaryMultiLabelClassifier(nn.Module):
    def __init__(self, num_labels):
        super().__init__()
        self.bert = BertModel.from_pretrained("bert-base-uncased")
        self.dropout = nn.Dropout(0.3)
        self.classifier = nn.Linear(self.bert.config.hidden_size, num_labels)

    def forward(self, input_ids, attention_mask):
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        pooled = self.dropout(outputs.pooler_output)
        return self.classifier(pooled)  # raw logits for BCEWithLogitsLoss

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
# Out:
# cuda

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

nltk.download('all')
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.corpus import wordnet as wn

lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

custom_stopwords = stop_words - {'not', 'no'}
custom_stopwords.update({'he', 'she', 'it', 'they', 'them', 'his', 'her', 'hers', 'him', 'you', 'your', 'yourself', 'etc', 'anything', 'else', 'early' , 'access'})

auxiliary_verbs = {
    'would', 'could', 'should', 'might', 'may', 'must', 'will', 'can', 'does', 'did', 'do',
    'am', 'is', 'are', 'was', 'were', 'been', 'being',
    'has', 'have', 'had',
    'shall', 'ought', 'shall',
    'need', 'dare', 'used'
}

contraction_mapping = {
    "wouldn't": "would not",
    "wouldnt" : "would not",
    "couldn't": "could not",
    "couldnt": "could not",
    "shouldn't": "should not",
    "shouldnt": "should not",
    "mightn't": "might not",
    "mightnt": "might not",
    "mustn't": "must not",
    "mustnt": "must not",
    "doesn't": "does not",
    "doesnt": "does not",
    "don't": "do not",
    "dont": "do not",
    "didn't": "did not",
    "didnt": "did not",
    "aren't": "are not",
    "arent": "are not",
    "isn't": "is not",
    "isnt": "is not",
    "wasn't": "was not",
    "wasnt": "was not",
    "weren't": "were not",
    "werent": "were not",
    "hasn't": "has not",
    "hasnt": "has not",
    "haven't": "have not",
    "havent": "have not",
    "hadn't": "had not",
    "hadnt": "had not",
    "won't": "will not",
    "wont": "will not",
    "can't": "can not",
    "cant": "can not",
    "ain't": "am not",
    "aint" : "am not",
    "should've": "should have",
    "shouldve": "should have",
    "could've": "could have",
    "couldve": "could have",
    "would've": "would have",
    "wouldve": "would have",
    "might've": "might have",
    "mightve": "might have",
    "must've": "must have",
    "mustve": "must have",
    "haven't": "have not",
    "had've": "had have",
    "hadve": "had have",
    "needn't": "need not",
    "neednt": "need not",
    "dare'nt": "dare not",
    "darent": "dare not",
    "used'nt": "used not",
    "usednt": "used not",
    "im": "i am",
    "youre": "you are",
    "youve": "you have",
    "youll": "you will",
    "youre": "you are",
    "youve": "you have",
    "youll": "you will",
    "hes": "he is",
    "shes": "she is",
    "its": "it is",
    "theyre": "they are",
    "theyve": "they have",
    "theyll": "they will",
    "i've": "i have",
    "we're": "we are",
    "we've": "we have",
    "we'll": "we will",
    "ive": "i have",
    "ill": "i will",
    "i'll": "i will",
    "we'll": "we will",
    "you'll": "you will",
}

def preprocess_text(text):
    return str(text).replace('&gt', '').replace('\n', ' ').strip().lower()

def expand_contractions(text):

    for contraction, expanded in contraction_mapping.items():
        text = re.sub(r'\b' + re.escape(contraction) + r'\b', expanded, text, flags=re.IGNORECASE)
    return text

def preprocess_text1(text, protected_keywords=None):

    text = expand_contractions(text)

    text = re.sub(r'[^a-zA-Z\s]', '', text)

    tokens = word_tokenize(text)

    tokens = [
        lemmatizer.lemmatize(word.lower(), pos=wn.VERB)
        for word in tokens
        if word.lower() not in custom_stopwords and word.lower() not in auxiliary_verbs and not word.isdigit()
    ]

    return ' '.join(tokens)

sample_text = " cant The brown isnt fox im am aint jump ive over combining the combined lazy dog. It's not a bright sunny day!. 2133d"
processed_text = preprocess_text1(sample_text)
print("Original Text:", sample_text)
print("Processed Text:", processed_text)
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_rus is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package bcp47 to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bcp47 is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package english_wordnet to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package english_wordnet is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker_tab to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker_tab is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger_tab to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger_tab is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package punkt_tab to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt_tab is already up-to-date!
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package tagsets_json to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package tagsets_json is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet2022 to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2022 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Original Text:  cant The brown isnt fox im am aint jump ive over combining the combined lazy dog. It's not a bright sunny day!. 2133d
# Processed Text: not brown not fox not jump combine combine lazy dog not bright sunny day

# %%
def adjust_prediction_with_negation(text, prob, flip_threshold=0.7):
    text = text.lower()
    tokens = re.findall(r'\w+', text)

    for i, word in enumerate(tokens):
        if word in {"not", "no"}:
            scope = tokens[i+1:i+4]
            if scope:
                if prob >= flip_threshold:
                    prob = 1 - prob * 0.9
                elif prob <= 1 - flip_threshold:
                    prob = 1 - prob * 0.9
                break
    return prob

# %% [markdown]
# ### Class Assigner Model

# %%
df = pd.read_csv('/content/Relabeled_Cleaned_Story_Fixed.csv',  encoding='ISO-8859-1')
df.head()
print(df.shape)
df['user_suggestion'] = df['user_suggestion'].replace({'Recommended': 1, 'Not Recommended': 0})
df.head()
label_columns = ["gameplay_mechanics", "visual_quality", "story_depth","pricing_and_value", "bugs_and_stability"]
X = df["user_review"]
y = df[label_columns].values.astype(np.float32)
# Out:
# (31585, 7)

# %%
X = X.apply(preprocess_text)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=0)

train_encodings = tokenizer(X_train.tolist(), truncation=True, padding="max_length", max_length=256, return_tensors="pt")
val_encodings = tokenizer(X_val.tolist(), truncation=True, padding="max_length", max_length=256, return_tensors="pt")

train_dataset = TensorDataset(train_encodings['input_ids'], train_encodings['attention_mask'], torch.tensor(y_train))
val_dataset = TensorDataset(val_encodings['input_ids'], val_encodings['attention_mask'], torch.tensor(y_val))

train_loader = DataLoader(train_dataset, sampler=RandomSampler(train_dataset), batch_size=64)
val_loader = DataLoader(val_dataset, sampler=SequentialSampler(val_dataset), batch_size=64)

# %%
model = BertBinaryMultiLabelClassifier(num_labels=len(label_columns)).to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-5, weight_decay=0.01)
loss_fn = nn.BCEWithLogitsLoss()

clip_value =50.0
epochs = 3

for epoch in range(epochs):
    model.train()
    total_loss = 0
    for step, batch in enumerate(train_loader):
        b_input_ids, b_input_mask, b_labels = [b.to(device) for b in batch]
        model.zero_grad()
        logits = model(b_input_ids, b_input_mask)
        loss = loss_fn(logits, b_labels.float())
        loss.backward()

        if step % 100 == 0:
            print(f"\n--- Gradient Report at Step {step}, Epoch {epoch+1} ---")
            for name, param in model.named_parameters():
                if param.requires_grad and param.grad is not None:
                    print(f"{name}: grad min = {param.grad.min():.6f}, grad max = {param.grad.max():.6f}")

        clip_grad_norm_(model.parameters(), clip_value)
        optimizer.step()
        total_loss += loss.item()

    print(f"Epoch {epoch+1} Loss: {total_loss / len(train_loader):.4f}")

model.eval()
predictions, true_labels = [], []

with torch.no_grad():
    for batch in val_loader:
        b_input_ids, b_input_mask, b_labels = [b.to(device) for b in batch]
        logits = model(b_input_ids, b_input_mask)
        probs = torch.sigmoid(logits).cpu().numpy()
        predictions.extend(probs)
        true_labels.extend(b_labels.cpu().numpy())

pred_array = np.array(predictions)
pred_labels = (pred_array >= 0.5).astype(int)
true_labels = np.array(true_labels)

f1 = f1_score(true_labels, pred_labels, average='macro')
print("\nMacro F1 Score (binary multi-label):", round(f1, 4))

print("\nClassification Report:")
print(classification_report(true_labels, pred_labels, target_names=label_columns))
# Out:
# --- Gradient Report at Step 0, Epoch 1 ---
# bert.embeddings.word_embeddings.weight: grad min = -0.006132, grad max = 0.004829
# bert.embeddings.position_embeddings.weight: grad min = -0.006639, grad max = 0.005507
# bert.embeddings.token_type_embeddings.weight: grad min = -0.024659, grad max = 0.023417
# bert.embeddings.LayerNorm.weight: grad min = -0.003387, grad max = 0.001892
# bert.embeddings.LayerNorm.bias: grad min = -0.001438, grad max = 0.001354
# bert.encoder.layer.0.attention.self.query.weight: grad min = -0.001225, grad max = 0.000499
# bert.encoder.layer.0.attention.self.query.bias: grad min = -0.000142, grad max = 0.000187
# bert.encoder.layer.0.attention.self.key.weight: grad min = -0.000485, grad max = 0.000477
# bert.encoder.layer.0.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.0.attention.self.value.weight: grad min = -0.003010, grad max = 0.002802
# bert.encoder.layer.0.attention.self.value.bias: grad min = -0.000756, grad max = 0.001126
# bert.encoder.layer.0.attention.output.dense.weight: grad min = -0.000614, grad max = 0.000777
# bert.encoder.layer.0.attention.output.dense.bias: grad min = -0.000913, grad max = 0.000801
# bert.encoder.layer.0.attention.output.LayerNorm.weight: grad min = -0.001091, grad max = 0.000412
# bert.encoder.layer.0.attention.output.LayerNorm.bias: grad min = -0.000659, grad max = 0.000562
# bert.encoder.layer.0.intermediate.dense.weight: grad min = -0.008590, grad max = 0.014813
# bert.encoder.layer.0.intermediate.dense.bias: grad min = -0.000563, grad max = 0.000505
# bert.encoder.layer.0.output.dense.weight: grad min = -0.001872, grad max = 0.001008
# bert.encoder.layer.0.output.dense.bias: grad min = -0.000657, grad max = 0.000517
# bert.encoder.layer.0.output.LayerNorm.weight: grad min = -0.006775, grad max = 0.001924
# bert.encoder.layer.0.output.LayerNorm.bias: grad min = -0.001133, grad max = 0.001078
# bert.encoder.layer.1.attention.self.query.weight: grad min = -0.000696, grad max = 0.000735
# bert.encoder.layer.1.attention.self.query.bias: grad min = -0.000285, grad max = 0.000245
# bert.encoder.layer.1.attention.self.key.weight: grad min = -0.001016, grad max = 0.001467
# bert.encoder.layer.1.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.1.attention.self.value.weight: grad min = -0.009043, grad max = 0.004965
# bert.encoder.layer.1.attention.self.value.bias: grad min = -0.000892, grad max = 0.001642
# bert.encoder.layer.1.attention.output.dense.weight: grad min = -0.001063, grad max = 0.000768
# bert.encoder.layer.1.attention.output.dense.bias: grad min = -0.000948, grad max = 0.000719
# bert.encoder.layer.1.attention.output.LayerNorm.weight: grad min = -0.001095, grad max = 0.000663
# bert.encoder.layer.1.attention.output.LayerNorm.bias: grad min = -0.000829, grad max = 0.000623
# bert.encoder.layer.1.intermediate.dense.weight: grad min = -0.013978, grad max = 0.009824
# bert.encoder.layer.1.intermediate.dense.bias: grad min = -0.000571, grad max = 0.001515
# bert.encoder.layer.1.output.dense.weight: grad min = -0.001243, grad max = 0.001055
# bert.encoder.layer.1.output.dense.bias: grad min = -0.000696, grad max = 0.000711
# bert.encoder.layer.1.output.LayerNorm.weight: grad min = -0.001344, grad max = 0.002378
# bert.encoder.layer.1.output.LayerNorm.bias: grad min = -0.001063, grad max = 0.000987
# bert.encoder.layer.2.attention.self.query.weight: grad min = -0.001670, grad max = 0.001597
# bert.encoder.layer.2.attention.self.query.bias: grad min = -0.000144, grad max = 0.000132
# bert.encoder.layer.2.attention.self.key.weight: grad min = -0.000533, grad max = 0.000682
# bert.encoder.layer.2.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.2.attention.self.value.weight: grad min = -0.007357, grad max = 0.006339
# bert.encoder.layer.2.attention.self.value.bias: grad min = -0.000820, grad max = 0.001008
# bert.encoder.layer.2.attention.output.dense.weight: grad min = -0.001545, grad max = 0.001094
# bert.encoder.layer.2.attention.output.dense.bias: grad min = -0.001177, grad max = 0.000839
# bert.encoder.layer.2.attention.output.LayerNorm.weight: grad min = -0.000729, grad max = 0.000501
# bert.encoder.layer.2.attention.output.LayerNorm.bias: grad min = -0.000976, grad max = 0.001233
# bert.encoder.layer.2.intermediate.dense.weight: grad min = -0.009630, grad max = 0.016697
# bert.encoder.layer.2.intermediate.dense.bias: grad min = -0.000570, grad max = 0.000509
# bert.encoder.layer.2.output.dense.weight: grad min = -0.001781, grad max = 0.002505
# bert.encoder.layer.2.output.dense.bias: grad min = -0.000985, grad max = 0.000971
# bert.encoder.layer.2.output.LayerNorm.weight: grad min = -0.005080, grad max = 0.001025
# bert.encoder.layer.2.output.LayerNorm.bias: grad min = -0.001655, grad max = 0.002910
# bert.encoder.layer.3.attention.self.query.weight: grad min = -0.002194, grad max = 0.001728
# bert.encoder.layer.3.attention.self.query.bias: grad min = -0.000208, grad max = 0.000368
# bert.encoder.layer.3.attention.self.key.weight: grad min = -0.000738, grad max = 0.000683
# bert.encoder.layer.3.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.3.attention.self.value.weight: grad min = -0.009056, grad max = 0.008445
# bert.encoder.layer.3.attention.self.value.bias: grad min = -0.001133, grad max = 0.001318
# bert.encoder.layer.3.attention.output.dense.weight: grad min = -0.003686, grad max = 0.003578
# bert.encoder.layer.3.attention.output.dense.bias: grad min = -0.001220, grad max = 0.003186
# bert.encoder.layer.3.attention.output.LayerNorm.weight: grad min = -0.000576, grad max = 0.000560
# bert.encoder.layer.3.attention.output.LayerNorm.bias: grad min = -0.001183, grad max = 0.001053
# bert.encoder.layer.3.intermediate.dense.weight: grad min = -0.020164, grad max = 0.028018
# bert.encoder.layer.3.intermediate.dense.bias: grad min = -0.001179, grad max = 0.000611
# bert.encoder.layer.3.output.dense.weight: grad min = -0.002041, grad max = 0.002836
# bert.encoder.layer.3.output.dense.bias: grad min = -0.001093, grad max = 0.001164
# bert.encoder.layer.3.output.LayerNorm.weight: grad min = -0.005448, grad max = 0.001159
# bert.encoder.layer.3.output.LayerNorm.bias: grad min = -0.001635, grad max = 0.001959
# bert.encoder.layer.4.attention.self.query.weight: grad min = -0.003184, grad max = 0.003956
# bert.encoder.layer.4.attention.self.query.bias: grad min = -0.000380, grad max = 0.000278
# bert.encoder.layer.4.attention.self.key.weight: grad min = -0.001421, grad max = 0.001565
# bert.encoder.layer.4.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.4.attention.self.value.weight: grad min = -0.014738, grad max = 0.005951
# bert.encoder.layer.4.attention.self.value.bias: grad min = -0.001106, grad max = 0.002572
# bert.encoder.layer.4.attention.output.dense.weight: grad min = -0.001884, grad max = 0.002069
# bert.encoder.layer.4.attention.output.dense.bias: grad min = -0.001151, grad max = 0.002402
# bert.encoder.layer.4.attention.output.LayerNorm.weight: grad min = -0.002749, grad max = 0.000701
# bert.encoder.layer.4.attention.output.LayerNorm.bias: grad min = -0.001002, grad max = 0.000952
# bert.encoder.layer.4.intermediate.dense.weight: grad min = -0.023545, grad max = 0.013224
# bert.encoder.layer.4.intermediate.dense.bias: grad min = -0.000518, grad max = 0.001845
# bert.encoder.layer.4.output.dense.weight: grad min = -0.003052, grad max = 0.002687
# bert.encoder.layer.4.output.dense.bias: grad min = -0.001175, grad max = 0.001024
# bert.encoder.layer.4.output.LayerNorm.weight: grad min = -0.007203, grad max = 0.005301
# bert.encoder.layer.4.output.LayerNorm.bias: grad min = -0.001930, grad max = 0.001771
# bert.encoder.layer.5.attention.self.query.weight: grad min = -0.002028, grad max = 0.002423
# bert.encoder.layer.5.attention.self.query.bias: grad min = -0.000289, grad max = 0.000242
# bert.encoder.layer.5.attention.self.key.weight: grad min = -0.003000, grad max = 0.002186
# bert.encoder.layer.5.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.5.attention.self.value.weight: grad min = -0.007949, grad max = 0.008514
# bert.encoder.layer.5.attention.self.value.bias: grad min = -0.001595, grad max = 0.001613
# bert.encoder.layer.5.attention.output.dense.weight: grad min = -0.001179, grad max = 0.001127
# bert.encoder.layer.5.attention.output.dense.bias: grad min = -0.001467, grad max = 0.002613
# bert.encoder.layer.5.attention.output.LayerNorm.weight: grad min = -0.004939, grad max = 0.000776
# bert.encoder.layer.5.attention.output.LayerNorm.bias: grad min = -0.001339, grad max = 0.001118
# bert.encoder.layer.5.intermediate.dense.weight: grad min = -0.017587, grad max = 0.017465
# bert.encoder.layer.5.intermediate.dense.bias: grad min = -0.000460, grad max = 0.000734
# bert.encoder.layer.5.output.dense.weight: grad min = -0.001398, grad max = 0.001899
# bert.encoder.layer.5.output.dense.bias: grad min = -0.001381, grad max = 0.001170
# bert.encoder.layer.5.output.LayerNorm.weight: grad min = -0.010829, grad max = 0.000787
# bert.encoder.layer.5.output.LayerNorm.bias: grad min = -0.002151, grad max = 0.002432
# bert.encoder.layer.6.attention.self.query.weight: grad min = -0.001652, grad max = 0.002060
# bert.encoder.layer.6.attention.self.query.bias: grad min = -0.000193, grad max = 0.000316
# bert.encoder.layer.6.attention.self.key.weight: grad min = -0.002875, grad max = 0.003768
# bert.encoder.layer.6.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.6.attention.self.value.weight: grad min = -0.009719, grad max = 0.011911
# bert.encoder.layer.6.attention.self.value.bias: grad min = -0.001635, grad max = 0.001574
# bert.encoder.layer.6.attention.output.dense.weight: grad min = -0.001261, grad max = 0.002290
# bert.encoder.layer.6.attention.output.dense.bias: grad min = -0.001572, grad max = 0.002815
# bert.encoder.layer.6.attention.output.LayerNorm.weight: grad min = -0.005047, grad max = 0.000731
# bert.encoder.layer.6.attention.output.LayerNorm.bias: grad min = -0.001527, grad max = 0.001393
# bert.encoder.layer.6.intermediate.dense.weight: grad min = -0.063689, grad max = 0.013249
# bert.encoder.layer.6.intermediate.dense.bias: grad min = -0.000659, grad max = 0.000758
# bert.encoder.layer.6.output.dense.weight: grad min = -0.001488, grad max = 0.001703
# bert.encoder.layer.6.output.dense.bias: grad min = -0.001520, grad max = 0.001563
# bert.encoder.layer.6.output.LayerNorm.weight: grad min = -0.021888, grad max = 0.001013
# bert.encoder.layer.6.output.LayerNorm.bias: grad min = -0.001916, grad max = 0.002596
# bert.encoder.layer.7.attention.self.query.weight: grad min = -0.001552, grad max = 0.001735
# bert.encoder.layer.7.attention.self.query.bias: grad min = -0.000145, grad max = 0.000162
# bert.encoder.layer.7.attention.self.key.weight: grad min = -0.001322, grad max = 0.001237
# bert.encoder.layer.7.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.7.attention.self.value.weight: grad min = -0.011272, grad max = 0.011213
# bert.encoder.layer.7.attention.self.value.bias: grad min = -0.001333, grad max = 0.001214
# bert.encoder.layer.7.attention.output.dense.weight: grad min = -0.001089, grad max = 0.001080
# bert.encoder.layer.7.attention.output.dense.bias: grad min = -0.001935, grad max = 0.002583
# bert.encoder.layer.7.attention.output.LayerNorm.weight: grad min = -0.007824, grad max = 0.000922
# bert.encoder.layer.7.attention.output.LayerNorm.bias: grad min = -0.001779, grad max = 0.001827
# bert.encoder.layer.7.intermediate.dense.weight: grad min = -0.026604, grad max = 0.057318
# bert.encoder.layer.7.intermediate.dense.bias: grad min = -0.001004, grad max = 0.001312
# bert.encoder.layer.7.output.dense.weight: grad min = -0.003646, grad max = 0.004631
# bert.encoder.layer.7.output.dense.bias: grad min = -0.001718, grad max = 0.001665
# bert.encoder.layer.7.output.LayerNorm.weight: grad min = -0.010157, grad max = 0.001457
# bert.encoder.layer.7.output.LayerNorm.bias: grad min = -0.002531, grad max = 0.003080
# bert.encoder.layer.8.attention.self.query.weight: grad min = -0.008906, grad max = 0.007140
# bert.encoder.layer.8.attention.self.query.bias: grad min = -0.000804, grad max = 0.001044
# bert.encoder.layer.8.attention.self.key.weight: grad min = -0.003191, grad max = 0.003122
# bert.encoder.layer.8.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.8.attention.self.value.weight: grad min = -0.020835, grad max = 0.016764
# bert.encoder.layer.8.attention.self.value.bias: grad min = -0.002553, grad max = 0.002842
# bert.encoder.layer.8.attention.output.dense.weight: grad min = -0.002799, grad max = 0.002286
# bert.encoder.layer.8.attention.output.dense.bias: grad min = -0.002014, grad max = 0.002818
# bert.encoder.layer.8.attention.output.LayerNorm.weight: grad min = -0.014126, grad max = 0.001023
# bert.encoder.layer.8.attention.output.LayerNorm.bias: grad min = -0.001853, grad max = 0.001941
# bert.encoder.layer.8.intermediate.dense.weight: grad min = -0.014990, grad max = 0.064493
# bert.encoder.layer.8.intermediate.dense.bias: grad min = -0.002050, grad max = 0.000978
# bert.encoder.layer.8.output.dense.weight: grad min = -0.001777, grad max = 0.002569
# bert.encoder.layer.8.output.dense.bias: grad min = -0.001798, grad max = 0.002246
# bert.encoder.layer.8.output.LayerNorm.weight: grad min = -0.008772, grad max = 0.001941
# bert.encoder.layer.8.output.LayerNorm.bias: grad min = -0.002202, grad max = 0.002843
# bert.encoder.layer.9.attention.self.query.weight: grad min = -0.004206, grad max = 0.003053
# bert.encoder.layer.9.attention.self.query.bias: grad min = -0.000388, grad max = 0.000390
# bert.encoder.layer.9.attention.self.key.weight: grad min = -0.002766, grad max = 0.002860
# bert.encoder.layer.9.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.9.attention.self.value.weight: grad min = -0.013273, grad max = 0.022750
# bert.encoder.layer.9.attention.self.value.bias: grad min = -0.005600, grad max = 0.002916
# bert.encoder.layer.9.attention.output.dense.weight: grad min = -0.003302, grad max = 0.004787
# bert.encoder.layer.9.attention.output.dense.bias: grad min = -0.002922, grad max = 0.002001
# bert.encoder.layer.9.attention.output.LayerNorm.weight: grad min = -0.011822, grad max = 0.002140
# bert.encoder.layer.9.attention.output.LayerNorm.bias: grad min = -0.002111, grad max = 0.001953
# bert.encoder.layer.9.intermediate.dense.weight: grad min = -0.035590, grad max = 0.027540
# bert.encoder.layer.9.intermediate.dense.bias: grad min = -0.001426, grad max = 0.004029
# bert.encoder.layer.9.output.dense.weight: grad min = -0.003553, grad max = 0.003915
# bert.encoder.layer.9.output.dense.bias: grad min = -0.003008, grad max = 0.002168
# bert.encoder.layer.9.output.LayerNorm.weight: grad min = -0.012212, grad max = 0.002348
# bert.encoder.layer.9.output.LayerNorm.bias: grad min = -0.003698, grad max = 0.002703
# bert.encoder.layer.10.attention.self.query.weight: grad min = -0.005814, grad max = 0.003328
# bert.encoder.layer.10.attention.self.query.bias: grad min = -0.000533, grad max = 0.000828
# bert.encoder.layer.10.attention.self.key.weight: grad min = -0.003305, grad max = 0.006266
# bert.encoder.layer.10.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.10.attention.self.value.weight: grad min = -0.027085, grad max = 0.036577
# bert.encoder.layer.10.attention.self.value.bias: grad min = -0.008759, grad max = 0.005361
# bert.encoder.layer.10.attention.output.dense.weight: grad min = -0.002499, grad max = 0.002860
# bert.encoder.layer.10.attention.output.dense.bias: grad min = -0.001986, grad max = 0.002228
# bert.encoder.layer.10.attention.output.LayerNorm.weight: grad min = -0.013102, grad max = 0.002393
# bert.encoder.layer.10.attention.output.LayerNorm.bias: grad min = -0.001973, grad max = 0.002097
# bert.encoder.layer.10.intermediate.dense.weight: grad min = -0.025677, grad max = 0.089069
# bert.encoder.layer.10.intermediate.dense.bias: grad min = -0.008746, grad max = 0.002480
# bert.encoder.layer.10.output.dense.weight: grad min = -0.002891, grad max = 0.003303
# bert.encoder.layer.10.output.dense.bias: grad min = -0.001902, grad max = 0.002451
# bert.encoder.layer.10.output.LayerNorm.weight: grad min = -0.008286, grad max = 0.003167
# bert.encoder.layer.10.output.LayerNorm.bias: grad min = -0.003052, grad max = 0.003461
# bert.encoder.layer.11.attention.self.query.weight: grad min = -0.003318, grad max = 0.004109
# bert.encoder.layer.11.attention.self.query.bias: grad min = -0.000609, grad max = 0.000462
# bert.encoder.layer.11.attention.self.key.weight: grad min = -0.003346, grad max = 0.001172
# bert.encoder.layer.11.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.11.attention.self.value.weight: grad min = -0.043506, grad max = 0.037235
# bert.encoder.layer.11.attention.self.value.bias: grad min = -0.003824, grad max = 0.004530
# bert.encoder.layer.11.attention.output.dense.weight: grad min = -0.002227, grad max = 0.002016
# bert.encoder.layer.11.attention.output.dense.bias: grad min = -0.001186, grad max = 0.001314
# bert.encoder.layer.11.attention.output.LayerNorm.weight: grad min = -0.003158, grad max = 0.001281
# bert.encoder.layer.11.attention.output.LayerNorm.bias: grad min = -0.001013, grad max = 0.001018
# bert.encoder.layer.11.intermediate.dense.weight: grad min = -0.021050, grad max = 0.012708
# bert.encoder.layer.11.intermediate.dense.bias: grad min = -0.000614, grad max = 0.001040
# bert.encoder.layer.11.output.dense.weight: grad min = -0.003087, grad max = 0.002972
# bert.encoder.layer.11.output.dense.bias: grad min = -0.000976, grad max = 0.000899
# bert.encoder.layer.11.output.LayerNorm.weight: grad min = -0.008616, grad max = 0.002156
# bert.encoder.layer.11.output.LayerNorm.bias: grad min = -0.001837, grad max = 0.001752
# bert.pooler.dense.weight: grad min = -0.017272, grad max = 0.019773
# bert.pooler.dense.bias: grad min = -0.003499, grad max = 0.003080
# classifier.weight: grad min = -0.077361, grad max = 0.067746
# classifier.bias: grad min = -0.057188, grad max = 0.032753
#
# --- Gradient Report at Step 100, Epoch 1 ---
# bert.embeddings.word_embeddings.weight: grad min = -0.003009, grad max = 0.003304
# bert.embeddings.position_embeddings.weight: grad min = -0.002071, grad max = 0.002148
# bert.embeddings.token_type_embeddings.weight: grad min = -0.026930, grad max = 0.024272
# bert.embeddings.LayerNorm.weight: grad min = -0.001909, grad max = 0.004208
# bert.embeddings.LayerNorm.bias: grad min = -0.001624, grad max = 0.001556
# bert.encoder.layer.0.attention.self.query.weight: grad min = -0.000909, grad max = 0.001231
# bert.encoder.layer.0.attention.self.query.bias: grad min = -0.000479, grad max = 0.000256
# bert.encoder.layer.0.attention.self.key.weight: grad min = -0.000658, grad max = 0.000738
# bert.encoder.layer.0.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.0.attention.self.value.weight: grad min = -0.002499, grad max = 0.003686
# bert.encoder.layer.0.attention.self.value.bias: grad min = -0.001647, grad max = 0.001547
# bert.encoder.layer.0.attention.output.dense.weight: grad min = -0.001159, grad max = 0.001045
# bert.encoder.layer.0.attention.output.dense.bias: grad min = -0.000915, grad max = 0.001054
# bert.encoder.layer.0.attention.output.LayerNorm.weight: grad min = -0.000917, grad max = 0.000583
# bert.encoder.layer.0.attention.output.LayerNorm.bias: grad min = -0.000682, grad max = 0.000683
# bert.encoder.layer.0.intermediate.dense.weight: grad min = -0.024000, grad max = 0.013494
# bert.encoder.layer.0.intermediate.dense.bias: grad min = -0.000652, grad max = 0.000433
# bert.encoder.layer.0.output.dense.weight: grad min = -0.001259, grad max = 0.001973
# bert.encoder.layer.0.output.dense.bias: grad min = -0.000688, grad max = 0.000707
# bert.encoder.layer.0.output.LayerNorm.weight: grad min = -0.008691, grad max = 0.001525
# bert.encoder.layer.0.output.LayerNorm.bias: grad min = -0.001434, grad max = 0.001159
# bert.encoder.layer.1.attention.self.query.weight: grad min = -0.001420, grad max = 0.001328
# bert.encoder.layer.1.attention.self.query.bias: grad min = -0.000269, grad max = 0.000380
# bert.encoder.layer.1.attention.self.key.weight: grad min = -0.001745, grad max = 0.001612
# bert.encoder.layer.1.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.1.attention.self.value.weight: grad min = -0.007747, grad max = 0.006064
# bert.encoder.layer.1.attention.self.value.bias: grad min = -0.001004, grad max = 0.001135
# bert.encoder.layer.1.attention.output.dense.weight: grad min = -0.001237, grad max = 0.001203
# bert.encoder.layer.1.attention.output.dense.bias: grad min = -0.001012, grad max = 0.001109
# bert.encoder.layer.1.attention.output.LayerNorm.weight: grad min = -0.001440, grad max = 0.001025
# bert.encoder.layer.1.attention.output.LayerNorm.bias: grad min = -0.000929, grad max = 0.000951
# bert.encoder.layer.1.intermediate.dense.weight: grad min = -0.035972, grad max = 0.019668
# bert.encoder.layer.1.intermediate.dense.bias: grad min = -0.000463, grad max = 0.001202
# bert.encoder.layer.1.output.dense.weight: grad min = -0.001376, grad max = 0.001352
# bert.encoder.layer.1.output.dense.bias: grad min = -0.000957, grad max = 0.000932
# bert.encoder.layer.1.output.LayerNorm.weight: grad min = -0.000762, grad max = 0.001720
# bert.encoder.layer.1.output.LayerNorm.bias: grad min = -0.001193, grad max = 0.001079
# bert.encoder.layer.2.attention.self.query.weight: grad min = -0.002014, grad max = 0.001682
# bert.encoder.layer.2.attention.self.query.bias: grad min = -0.000265, grad max = 0.000301
# bert.encoder.layer.2.attention.self.key.weight: grad min = -0.001171, grad max = 0.001038
# bert.encoder.layer.2.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.2.attention.self.value.weight: grad min = -0.009113, grad max = 0.014273
# bert.encoder.layer.2.attention.self.value.bias: grad min = -0.001660, grad max = 0.001218
# bert.encoder.layer.2.attention.output.dense.weight: grad min = -0.001357, grad max = 0.001622
# bert.encoder.layer.2.attention.output.dense.bias: grad min = -0.001118, grad max = 0.001176
# bert.encoder.layer.2.attention.output.LayerNorm.weight: grad min = -0.000755, grad max = 0.001249
# bert.encoder.layer.2.attention.output.LayerNorm.bias: grad min = -0.001017, grad max = 0.001034
# bert.encoder.layer.2.intermediate.dense.weight: grad min = -0.015403, grad max = 0.014241
# bert.encoder.layer.2.intermediate.dense.bias: grad min = -0.000593, grad max = 0.001295
# bert.encoder.layer.2.output.dense.weight: grad min = -0.002275, grad max = 0.001615
# bert.encoder.layer.2.output.dense.bias: grad min = -0.000959, grad max = 0.000944
# bert.encoder.layer.2.output.LayerNorm.weight: grad min = -0.000929, grad max = 0.002750
# bert.encoder.layer.2.output.LayerNorm.bias: grad min = -0.001565, grad max = 0.001374
# bert.encoder.layer.3.attention.self.query.weight: grad min = -0.001511, grad max = 0.001497
# bert.encoder.layer.3.attention.self.query.bias: grad min = -0.000230, grad max = 0.000259
# bert.encoder.layer.3.attention.self.key.weight: grad min = -0.001126, grad max = 0.000889
# bert.encoder.layer.3.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.3.attention.self.value.weight: grad min = -0.011828, grad max = 0.012633
# bert.encoder.layer.3.attention.self.value.bias: grad min = -0.002046, grad max = 0.001977
# bert.encoder.layer.3.attention.output.dense.weight: grad min = -0.002205, grad max = 0.002073
# bert.encoder.layer.3.attention.output.dense.bias: grad min = -0.001304, grad max = 0.001475
# bert.encoder.layer.3.attention.output.LayerNorm.weight: grad min = -0.000823, grad max = 0.000969
# bert.encoder.layer.3.attention.output.LayerNorm.bias: grad min = -0.001141, grad max = 0.001387
# bert.encoder.layer.3.intermediate.dense.weight: grad min = -0.021799, grad max = 0.023340
# bert.encoder.layer.3.intermediate.dense.bias: grad min = -0.000703, grad max = 0.000481
# bert.encoder.layer.3.output.dense.weight: grad min = -0.001337, grad max = 0.001201
# bert.encoder.layer.3.output.dense.bias: grad min = -0.001069, grad max = 0.001338
# bert.encoder.layer.3.output.LayerNorm.weight: grad min = -0.001067, grad max = 0.014941
# bert.encoder.layer.3.output.LayerNorm.bias: grad min = -0.001697, grad max = 0.002001
# bert.encoder.layer.4.attention.self.query.weight: grad min = -0.002710, grad max = 0.002287
# bert.encoder.layer.4.attention.self.query.bias: grad min = -0.000283, grad max = 0.000350
# bert.encoder.layer.4.attention.self.key.weight: grad min = -0.001384, grad max = 0.001119
# bert.encoder.layer.4.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.4.attention.self.value.weight: grad min = -0.011520, grad max = 0.007868
# bert.encoder.layer.4.attention.self.value.bias: grad min = -0.001371, grad max = 0.001927
# bert.encoder.layer.4.attention.output.dense.weight: grad min = -0.001335, grad max = 0.001819
# bert.encoder.layer.4.attention.output.dense.bias: grad min = -0.001478, grad max = 0.002029
# bert.encoder.layer.4.attention.output.LayerNorm.weight: grad min = -0.000937, grad max = 0.001614
# bert.encoder.layer.4.attention.output.LayerNorm.bias: grad min = -0.001380, grad max = 0.001677
# bert.encoder.layer.4.intermediate.dense.weight: grad min = -0.047194, grad max = 0.025224
# bert.encoder.layer.4.intermediate.dense.bias: grad min = -0.001315, grad max = 0.000939
# bert.encoder.layer.4.output.dense.weight: grad min = -0.001507, grad max = 0.001565
# bert.encoder.layer.4.output.dense.bias: grad min = -0.001315, grad max = 0.001518
# bert.encoder.layer.4.output.LayerNorm.weight: grad min = -0.005002, grad max = 0.012720
# bert.encoder.layer.4.output.LayerNorm.bias: grad min = -0.001902, grad max = 0.002433
# bert.encoder.layer.5.attention.self.query.weight: grad min = -0.004021, grad max = 0.002259
# bert.encoder.layer.5.attention.self.query.bias: grad min = -0.000321, grad max = 0.000555
# bert.encoder.layer.5.attention.self.key.weight: grad min = -0.002018, grad max = 0.002156
# bert.encoder.layer.5.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.5.attention.self.value.weight: grad min = -0.011399, grad max = 0.009682
# bert.encoder.layer.5.attention.self.value.bias: grad min = -0.001328, grad max = 0.001662
# bert.encoder.layer.5.attention.output.dense.weight: grad min = -0.001425, grad max = 0.001292
# bert.encoder.layer.5.attention.output.dense.bias: grad min = -0.001460, grad max = 0.002031
# bert.encoder.layer.5.attention.output.LayerNorm.weight: grad min = -0.000998, grad max = 0.002516
# bert.encoder.layer.5.attention.output.LayerNorm.bias: grad min = -0.001327, grad max = 0.001780
# bert.encoder.layer.5.intermediate.dense.weight: grad min = -0.017540, grad max = 0.030058
# bert.encoder.layer.5.intermediate.dense.bias: grad min = -0.001251, grad max = 0.001383
# bert.encoder.layer.5.output.dense.weight: grad min = -0.001660, grad max = 0.001629
# bert.encoder.layer.5.output.dense.bias: grad min = -0.001364, grad max = 0.001602
# bert.encoder.layer.5.output.LayerNorm.weight: grad min = -0.025088, grad max = 0.002411
# bert.encoder.layer.5.output.LayerNorm.bias: grad min = -0.002271, grad max = 0.002217
# bert.encoder.layer.6.attention.self.query.weight: grad min = -0.007761, grad max = 0.008016
# bert.encoder.layer.6.attention.self.query.bias: grad min = -0.001363, grad max = 0.001294
# bert.encoder.layer.6.attention.self.key.weight: grad min = -0.011491, grad max = 0.009366
# bert.encoder.layer.6.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.6.attention.self.value.weight: grad min = -0.013314, grad max = 0.012729
# bert.encoder.layer.6.attention.self.value.bias: grad min = -0.002055, grad max = 0.002204
# bert.encoder.layer.6.attention.output.dense.weight: grad min = -0.001824, grad max = 0.001978
# bert.encoder.layer.6.attention.output.dense.bias: grad min = -0.001877, grad max = 0.002290
# bert.encoder.layer.6.attention.output.LayerNorm.weight: grad min = -0.000978, grad max = 0.004744
# bert.encoder.layer.6.attention.output.LayerNorm.bias: grad min = -0.001427, grad max = 0.002040
# bert.encoder.layer.6.intermediate.dense.weight: grad min = -0.014015, grad max = 0.029429
# bert.encoder.layer.6.intermediate.dense.bias: grad min = -0.001896, grad max = 0.001308
# bert.encoder.layer.6.output.dense.weight: grad min = -0.001306, grad max = 0.001523
# bert.encoder.layer.6.output.dense.bias: grad min = -0.001469, grad max = 0.001792
# bert.encoder.layer.6.output.LayerNorm.weight: grad min = -0.002364, grad max = 0.002519
# bert.encoder.layer.6.output.LayerNorm.bias: grad min = -0.002339, grad max = 0.002924
# bert.encoder.layer.7.attention.self.query.weight: grad min = -0.001675, grad max = 0.002164
# bert.encoder.layer.7.attention.self.query.bias: grad min = -0.000188, grad max = 0.000220
# bert.encoder.layer.7.attention.self.key.weight: grad min = -0.001529, grad max = 0.001260
# bert.encoder.layer.7.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.7.attention.self.value.weight: grad min = -0.011187, grad max = 0.011905
# bert.encoder.layer.7.attention.self.value.bias: grad min = -0.001718, grad max = 0.001267
# bert.encoder.layer.7.attention.output.dense.weight: grad min = -0.000968, grad max = 0.000816
# bert.encoder.layer.7.attention.output.dense.bias: grad min = -0.001812, grad max = 0.002179
# bert.encoder.layer.7.attention.output.LayerNorm.weight: grad min = -0.001097, grad max = 0.003490
# bert.encoder.layer.7.attention.output.LayerNorm.bias: grad min = -0.001645, grad max = 0.001698
# bert.encoder.layer.7.intermediate.dense.weight: grad min = -0.062954, grad max = 0.025094
# bert.encoder.layer.7.intermediate.dense.bias: grad min = -0.002145, grad max = 0.002879
# bert.encoder.layer.7.output.dense.weight: grad min = -0.001558, grad max = 0.001462
# bert.encoder.layer.7.output.dense.bias: grad min = -0.001579, grad max = 0.001592
# bert.encoder.layer.7.output.LayerNorm.weight: grad min = -0.001222, grad max = 0.003465
# bert.encoder.layer.7.output.LayerNorm.bias: grad min = -0.002652, grad max = 0.002934
# bert.encoder.layer.8.attention.self.query.weight: grad min = -0.003329, grad max = 0.002216
# bert.encoder.layer.8.attention.self.query.bias: grad min = -0.000327, grad max = 0.000653
# bert.encoder.layer.8.attention.self.key.weight: grad min = -0.001747, grad max = 0.002389
# bert.encoder.layer.8.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.8.attention.self.value.weight: grad min = -0.015240, grad max = 0.013095
# bert.encoder.layer.8.attention.self.value.bias: grad min = -0.002129, grad max = 0.002284
# bert.encoder.layer.8.attention.output.dense.weight: grad min = -0.002688, grad max = 0.002525
# bert.encoder.layer.8.attention.output.dense.bias: grad min = -0.002272, grad max = 0.002077
# bert.encoder.layer.8.attention.output.LayerNorm.weight: grad min = -0.001370, grad max = 0.002740
# bert.encoder.layer.8.attention.output.LayerNorm.bias: grad min = -0.001861, grad max = 0.001662
# bert.encoder.layer.8.intermediate.dense.weight: grad min = -0.058826, grad max = 0.022279
# bert.encoder.layer.8.intermediate.dense.bias: grad min = -0.001013, grad max = 0.001251
# bert.encoder.layer.8.output.dense.weight: grad min = -0.002302, grad max = 0.002210
# bert.encoder.layer.8.output.dense.bias: grad min = -0.001548, grad max = 0.001707
# bert.encoder.layer.8.output.LayerNorm.weight: grad min = -0.001394, grad max = 0.021455
# bert.encoder.layer.8.output.LayerNorm.bias: grad min = -0.002311, grad max = 0.002477
# bert.encoder.layer.9.attention.self.query.weight: grad min = -0.003660, grad max = 0.002446
# bert.encoder.layer.9.attention.self.query.bias: grad min = -0.000343, grad max = 0.000369
# bert.encoder.layer.9.attention.self.key.weight: grad min = -0.002300, grad max = 0.002348
# bert.encoder.layer.9.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.9.attention.self.value.weight: grad min = -0.015632, grad max = 0.010978
# bert.encoder.layer.9.attention.self.value.bias: grad min = -0.002220, grad max = 0.003198
# bert.encoder.layer.9.attention.output.dense.weight: grad min = -0.003088, grad max = 0.003643
# bert.encoder.layer.9.attention.output.dense.bias: grad min = -0.001810, grad max = 0.001727
# bert.encoder.layer.9.attention.output.LayerNorm.weight: grad min = -0.001037, grad max = 0.005911
# bert.encoder.layer.9.attention.output.LayerNorm.bias: grad min = -0.001512, grad max = 0.001534
# bert.encoder.layer.9.intermediate.dense.weight: grad min = -0.058482, grad max = 0.023831
# bert.encoder.layer.9.intermediate.dense.bias: grad min = -0.001084, grad max = 0.005532
# bert.encoder.layer.9.output.dense.weight: grad min = -0.002514, grad max = 0.002312
# bert.encoder.layer.9.output.dense.bias: grad min = -0.001912, grad max = 0.001657
# bert.encoder.layer.9.output.LayerNorm.weight: grad min = -0.004741, grad max = 0.004013
# bert.encoder.layer.9.output.LayerNorm.bias: grad min = -0.002697, grad max = 0.001787
# bert.encoder.layer.10.attention.self.query.weight: grad min = -0.003719, grad max = 0.002986
# bert.encoder.layer.10.attention.self.query.bias: grad min = -0.000348, grad max = 0.000471
# bert.encoder.layer.10.attention.self.key.weight: grad min = -0.003488, grad max = 0.005218
# bert.encoder.layer.10.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.10.attention.self.value.weight: grad min = -0.019128, grad max = 0.017012
# bert.encoder.layer.10.attention.self.value.bias: grad min = -0.003349, grad max = 0.002309
# bert.encoder.layer.10.attention.output.dense.weight: grad min = -0.002149, grad max = 0.001655
# bert.encoder.layer.10.attention.output.dense.bias: grad min = -0.001446, grad max = 0.001093
# bert.encoder.layer.10.attention.output.LayerNorm.weight: grad min = -0.001682, grad max = 0.010862
# bert.encoder.layer.10.attention.output.LayerNorm.bias: grad min = -0.001343, grad max = 0.001105
# bert.encoder.layer.10.intermediate.dense.weight: grad min = -0.039373, grad max = 0.085240
# bert.encoder.layer.10.intermediate.dense.bias: grad min = -0.005789, grad max = 0.001276
# bert.encoder.layer.10.output.dense.weight: grad min = -0.001587, grad max = 0.001492
# bert.encoder.layer.10.output.dense.bias: grad min = -0.000994, grad max = 0.001326
# bert.encoder.layer.10.output.LayerNorm.weight: grad min = -0.011923, grad max = 0.003035
# bert.encoder.layer.10.output.LayerNorm.bias: grad min = -0.001656, grad max = 0.001817
# bert.encoder.layer.11.attention.self.query.weight: grad min = -0.001991, grad max = 0.001733
# bert.encoder.layer.11.attention.self.query.bias: grad min = -0.000277, grad max = 0.000299
# bert.encoder.layer.11.attention.self.key.weight: grad min = -0.001752, grad max = 0.002855
# bert.encoder.layer.11.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.11.attention.self.value.weight: grad min = -0.018004, grad max = 0.012762
# bert.encoder.layer.11.attention.self.value.bias: grad min = -0.001607, grad max = 0.001903
# bert.encoder.layer.11.attention.output.dense.weight: grad min = -0.001411, grad max = 0.001662
# bert.encoder.layer.11.attention.output.dense.bias: grad min = -0.000737, grad max = 0.000916
# bert.encoder.layer.11.attention.output.LayerNorm.weight: grad min = -0.001632, grad max = 0.002977
# bert.encoder.layer.11.attention.output.LayerNorm.bias: grad min = -0.000580, grad max = 0.000620
# bert.encoder.layer.11.intermediate.dense.weight: grad min = -0.007436, grad max = 0.015538
# bert.encoder.layer.11.intermediate.dense.bias: grad min = -0.000964, grad max = 0.000610
# bert.encoder.layer.11.output.dense.weight: grad min = -0.001693, grad max = 0.001361
# bert.encoder.layer.11.output.dense.bias: grad min = -0.000553, grad max = 0.000416
# bert.encoder.layer.11.output.LayerNorm.weight: grad min = -0.001821, grad max = 0.005357
# bert.encoder.layer.11.output.LayerNorm.bias: grad min = -0.000793, grad max = 0.000670
# bert.pooler.dense.weight: grad min = -0.007081, grad max = 0.006270
# bert.pooler.dense.bias: grad min = -0.001940, grad max = 0.002233
# classifier.weight: grad min = -0.039545, grad max = 0.036117
# classifier.bias: grad min = -0.014811, grad max = 0.022779
#
# --- Gradient Report at Step 200, Epoch 1 ---
# bert.embeddings.word_embeddings.weight: grad min = -0.006378, grad max = 0.006643
# bert.embeddings.position_embeddings.weight: grad min = -0.006378, grad max = 0.003981
# bert.embeddings.token_type_embeddings.weight: grad min = -0.070875, grad max = 0.070506
# bert.embeddings.LayerNorm.weight: grad min = -0.007289, grad max = 0.020544
# bert.embeddings.LayerNorm.bias: grad min = -0.004331, grad max = 0.004268
# bert.encoder.layer.0.attention.self.query.weight: grad min = -0.004874, grad max = 0.004918
# bert.encoder.layer.0.attention.self.query.bias: grad min = -0.000587, grad max = 0.000771
# bert.encoder.layer.0.attention.self.key.weight: grad min = -0.001379, grad max = 0.001621
# bert.encoder.layer.0.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.0.attention.self.value.weight: grad min = -0.011911, grad max = 0.008784
# bert.encoder.layer.0.attention.self.value.bias: grad min = -0.003132, grad max = 0.003332
# bert.encoder.layer.0.attention.output.dense.weight: grad min = -0.002216, grad max = 0.001833
# bert.encoder.layer.0.attention.output.dense.bias: grad min = -0.002372, grad max = 0.003165
# bert.encoder.layer.0.attention.output.LayerNorm.weight: grad min = -0.001462, grad max = 0.006174
# bert.encoder.layer.0.attention.output.LayerNorm.bias: grad min = -0.001735, grad max = 0.002333
# bert.encoder.layer.0.intermediate.dense.weight: grad min = -0.051100, grad max = 0.078256
# bert.encoder.layer.0.intermediate.dense.bias: grad min = -0.001185, grad max = 0.001209
# bert.encoder.layer.0.output.dense.weight: grad min = -0.003749, grad max = 0.003539
# bert.encoder.layer.0.output.dense.bias: grad min = -0.001766, grad max = 0.002156
# bert.encoder.layer.0.output.LayerNorm.weight: grad min = -0.008589, grad max = 0.049753
# bert.encoder.layer.0.output.LayerNorm.bias: grad min = -0.002790, grad max = 0.003685
# bert.encoder.layer.1.attention.self.query.weight: grad min = -0.003668, grad max = 0.003112
# bert.encoder.layer.1.attention.self.query.bias: grad min = -0.000867, grad max = 0.000713
# bert.encoder.layer.1.attention.self.key.weight: grad min = -0.002509, grad max = 0.006055
# bert.encoder.layer.1.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.1.attention.self.value.weight: grad min = -0.015338, grad max = 0.018654
# bert.encoder.layer.1.attention.self.value.bias: grad min = -0.002882, grad max = 0.003130
# bert.encoder.layer.1.attention.output.dense.weight: grad min = -0.003019, grad max = 0.003980
# bert.encoder.layer.1.attention.output.dense.bias: grad min = -0.002792, grad max = 0.003100
# bert.encoder.layer.1.attention.output.LayerNorm.weight: grad min = -0.002153, grad max = 0.009587
# bert.encoder.layer.1.attention.output.LayerNorm.bias: grad min = -0.002331, grad max = 0.002580
# bert.encoder.layer.1.intermediate.dense.weight: grad min = -0.018168, grad max = 0.036392
# bert.encoder.layer.1.intermediate.dense.bias: grad min = -0.001468, grad max = 0.001312
# bert.encoder.layer.1.output.dense.weight: grad min = -0.002932, grad max = 0.003028
# bert.encoder.layer.1.output.dense.bias: grad min = -0.002133, grad max = 0.002523
# bert.encoder.layer.1.output.LayerNorm.weight: grad min = -0.005473, grad max = 0.001793
# bert.encoder.layer.1.output.LayerNorm.bias: grad min = -0.003051, grad max = 0.003329
# bert.encoder.layer.2.attention.self.query.weight: grad min = -0.006624, grad max = 0.005733
# bert.encoder.layer.2.attention.self.query.bias: grad min = -0.001053, grad max = 0.001244
# bert.encoder.layer.2.attention.self.key.weight: grad min = -0.002661, grad max = 0.003459
# bert.encoder.layer.2.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.2.attention.self.value.weight: grad min = -0.017925, grad max = 0.017535
# bert.encoder.layer.2.attention.self.value.bias: grad min = -0.001909, grad max = 0.002117
# bert.encoder.layer.2.attention.output.dense.weight: grad min = -0.003007, grad max = 0.003913
# bert.encoder.layer.2.attention.output.dense.bias: grad min = -0.002725, grad max = 0.003447
# bert.encoder.layer.2.attention.output.LayerNorm.weight: grad min = -0.002150, grad max = 0.007095
# bert.encoder.layer.2.attention.output.LayerNorm.bias: grad min = -0.002455, grad max = 0.003065
# bert.encoder.layer.2.intermediate.dense.weight: grad min = -0.021432, grad max = 0.021103
# bert.encoder.layer.2.intermediate.dense.bias: grad min = -0.001117, grad max = 0.001667
# bert.encoder.layer.2.output.dense.weight: grad min = -0.002408, grad max = 0.002917
# bert.encoder.layer.2.output.dense.bias: grad min = -0.003137, grad max = 0.002971
# bert.encoder.layer.2.output.LayerNorm.weight: grad min = -0.001991, grad max = 0.032750
# bert.encoder.layer.2.output.LayerNorm.bias: grad min = -0.005680, grad max = 0.003919
# bert.encoder.layer.3.attention.self.query.weight: grad min = -0.004355, grad max = 0.003636
# bert.encoder.layer.3.attention.self.query.bias: grad min = -0.000753, grad max = 0.000941
# bert.encoder.layer.3.attention.self.key.weight: grad min = -0.003074, grad max = 0.002099
# bert.encoder.layer.3.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.3.attention.self.value.weight: grad min = -0.025813, grad max = 0.020353
# bert.encoder.layer.3.attention.self.value.bias: grad min = -0.003205, grad max = 0.004100
# bert.encoder.layer.3.attention.output.dense.weight: grad min = -0.004447, grad max = 0.003480
# bert.encoder.layer.3.attention.output.dense.bias: grad min = -0.004633, grad max = 0.003716
# bert.encoder.layer.3.attention.output.LayerNorm.weight: grad min = -0.002097, grad max = 0.009234
# bert.encoder.layer.3.attention.output.LayerNorm.bias: grad min = -0.002490, grad max = 0.003252
# bert.encoder.layer.3.intermediate.dense.weight: grad min = -0.023684, grad max = 0.038317
# bert.encoder.layer.3.intermediate.dense.bias: grad min = -0.002100, grad max = 0.002173
# bert.encoder.layer.3.output.dense.weight: grad min = -0.002116, grad max = 0.002415
# bert.encoder.layer.3.output.dense.bias: grad min = -0.002845, grad max = 0.003445
# bert.encoder.layer.3.output.LayerNorm.weight: grad min = -0.002855, grad max = 0.032088
# bert.encoder.layer.3.output.LayerNorm.bias: grad min = -0.004956, grad max = 0.005221
# bert.encoder.layer.4.attention.self.query.weight: grad min = -0.005386, grad max = 0.004842
# bert.encoder.layer.4.attention.self.query.bias: grad min = -0.000930, grad max = 0.001037
# bert.encoder.layer.4.attention.self.key.weight: grad min = -0.004085, grad max = 0.003198
# bert.encoder.layer.4.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.4.attention.self.value.weight: grad min = -0.018858, grad max = 0.024103
# bert.encoder.layer.4.attention.self.value.bias: grad min = -0.004281, grad max = 0.003267
# bert.encoder.layer.4.attention.output.dense.weight: grad min = -0.003295, grad max = 0.002689
# bert.encoder.layer.4.attention.output.dense.bias: grad min = -0.003451, grad max = 0.003026
# bert.encoder.layer.4.attention.output.LayerNorm.weight: grad min = -0.003009, grad max = 0.009582
# bert.encoder.layer.4.attention.output.LayerNorm.bias: grad min = -0.003060, grad max = 0.002836
# bert.encoder.layer.4.intermediate.dense.weight: grad min = -0.026586, grad max = 0.031846
# bert.encoder.layer.4.intermediate.dense.bias: grad min = -0.001800, grad max = 0.001699
# bert.encoder.layer.4.output.dense.weight: grad min = -0.002615, grad max = 0.003060
# bert.encoder.layer.4.output.dense.bias: grad min = -0.003152, grad max = 0.003201
# bert.encoder.layer.4.output.LayerNorm.weight: grad min = -0.004182, grad max = 0.032536
# bert.encoder.layer.4.output.LayerNorm.bias: grad min = -0.004333, grad max = 0.004965
# bert.encoder.layer.5.attention.self.query.weight: grad min = -0.004629, grad max = 0.002118
# bert.encoder.layer.5.attention.self.query.bias: grad min = -0.000260, grad max = 0.000699
# bert.encoder.layer.5.attention.self.key.weight: grad min = -0.003558, grad max = 0.002908
# bert.encoder.layer.5.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.5.attention.self.value.weight: grad min = -0.017402, grad max = 0.020729
# bert.encoder.layer.5.attention.self.value.bias: grad min = -0.003511, grad max = 0.002596
# bert.encoder.layer.5.attention.output.dense.weight: grad min = -0.002444, grad max = 0.002947
# bert.encoder.layer.5.attention.output.dense.bias: grad min = -0.004356, grad max = 0.003746
# bert.encoder.layer.5.attention.output.LayerNorm.weight: grad min = -0.004040, grad max = 0.014258
# bert.encoder.layer.5.attention.output.LayerNorm.bias: grad min = -0.003617, grad max = 0.003545
# bert.encoder.layer.5.intermediate.dense.weight: grad min = -0.032012, grad max = 0.028880
# bert.encoder.layer.5.intermediate.dense.bias: grad min = -0.001143, grad max = 0.001996
# bert.encoder.layer.5.output.dense.weight: grad min = -0.003659, grad max = 0.003233
# bert.encoder.layer.5.output.dense.bias: grad min = -0.003971, grad max = 0.003402
# bert.encoder.layer.5.output.LayerNorm.weight: grad min = -0.005562, grad max = 0.051975
# bert.encoder.layer.5.output.LayerNorm.bias: grad min = -0.005555, grad max = 0.004967
# bert.encoder.layer.6.attention.self.query.weight: grad min = -0.010810, grad max = 0.008575
# bert.encoder.layer.6.attention.self.query.bias: grad min = -0.000950, grad max = 0.001260
# bert.encoder.layer.6.attention.self.key.weight: grad min = -0.006354, grad max = 0.007740
# bert.encoder.layer.6.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.6.attention.self.value.weight: grad min = -0.028458, grad max = 0.024990
# bert.encoder.layer.6.attention.self.value.bias: grad min = -0.003644, grad max = 0.003672
# bert.encoder.layer.6.attention.output.dense.weight: grad min = -0.003740, grad max = 0.003555
# bert.encoder.layer.6.attention.output.dense.bias: grad min = -0.003821, grad max = 0.003869
# bert.encoder.layer.6.attention.output.LayerNorm.weight: grad min = -0.005122, grad max = 0.013602
# bert.encoder.layer.6.attention.output.LayerNorm.bias: grad min = -0.003997, grad max = 0.004059
# bert.encoder.layer.6.intermediate.dense.weight: grad min = -0.055248, grad max = 0.033857
# bert.encoder.layer.6.intermediate.dense.bias: grad min = -0.003203, grad max = 0.004017
# bert.encoder.layer.6.output.dense.weight: grad min = -0.003932, grad max = 0.003277
# bert.encoder.layer.6.output.dense.bias: grad min = -0.003790, grad max = 0.003702
# bert.encoder.layer.6.output.LayerNorm.weight: grad min = -0.005495, grad max = 0.022935
# bert.encoder.layer.6.output.LayerNorm.bias: grad min = -0.005175, grad max = 0.005211
# bert.encoder.layer.7.attention.self.query.weight: grad min = -0.003090, grad max = 0.002348
# bert.encoder.layer.7.attention.self.query.bias: grad min = -0.000326, grad max = 0.000455
# bert.encoder.layer.7.attention.self.key.weight: grad min = -0.002104, grad max = 0.002155
# bert.encoder.layer.7.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.7.attention.self.value.weight: grad min = -0.022000, grad max = 0.027226
# bert.encoder.layer.7.attention.self.value.bias: grad min = -0.003310, grad max = 0.002623
# bert.encoder.layer.7.attention.output.dense.weight: grad min = -0.002062, grad max = 0.002224
# bert.encoder.layer.7.attention.output.dense.bias: grad min = -0.004121, grad max = 0.004335
# bert.encoder.layer.7.attention.output.LayerNorm.weight: grad min = -0.004661, grad max = 0.018460
# bert.encoder.layer.7.attention.output.LayerNorm.bias: grad min = -0.004052, grad max = 0.004179
# bert.encoder.layer.7.intermediate.dense.weight: grad min = -0.037410, grad max = 0.074899
# bert.encoder.layer.7.intermediate.dense.bias: grad min = -0.004349, grad max = 0.001679
# bert.encoder.layer.7.output.dense.weight: grad min = -0.003841, grad max = 0.003173
# bert.encoder.layer.7.output.dense.bias: grad min = -0.003510, grad max = 0.004059
# bert.encoder.layer.7.output.LayerNorm.weight: grad min = -0.004767, grad max = 0.015680
# ...
# bert.encoder.layer.2.attention.self.value.weight: grad min = -0.008290, grad max = 0.008266
# bert.encoder.layer.2.attention.self.value.bias: grad min = -0.000983, grad max = 0.001180
# bert.encoder.layer.2.attention.output.dense.weight: grad min = -0.001438, grad max = 0.001720
# bert.encoder.layer.2.attention.output.dense.bias: grad min = -0.001008, grad max = 0.001261
# bert.encoder.layer.2.attention.output.LayerNorm.weight: grad min = -0.001048, grad max = 0.001604
# bert.encoder.layer.2.attention.output.LayerNorm.bias: grad min = -0.000947, grad max = 0.001557
# bert.encoder.layer.2.intermediate.dense.weight: grad min = -0.010854, grad max = 0.012569
# bert.encoder.layer.2.intermediate.dense.bias: grad min = -0.001120, grad max = 0.000955
# bert.encoder.layer.2.output.dense.weight: grad min = -0.001540, grad max = 0.002501
# bert.encoder.layer.2.output.dense.bias: grad min = -0.001011, grad max = 0.001246
# bert.encoder.layer.2.output.LayerNorm.weight: grad min = -0.011589, grad max = 0.001745
# bert.encoder.layer.2.output.LayerNorm.bias: grad min = -0.001205, grad max = 0.002117
# bert.encoder.layer.3.attention.self.query.weight: grad min = -0.001635, grad max = 0.001668
# bert.encoder.layer.3.attention.self.query.bias: grad min = -0.000428, grad max = 0.000309
# bert.encoder.layer.3.attention.self.key.weight: grad min = -0.001886, grad max = 0.002388
# bert.encoder.layer.3.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.3.attention.self.value.weight: grad min = -0.005958, grad max = 0.007370
# bert.encoder.layer.3.attention.self.value.bias: grad min = -0.001440, grad max = 0.000957
# bert.encoder.layer.3.attention.output.dense.weight: grad min = -0.003847, grad max = 0.003291
# bert.encoder.layer.3.attention.output.dense.bias: grad min = -0.001244, grad max = 0.002371
# bert.encoder.layer.3.attention.output.LayerNorm.weight: grad min = -0.001277, grad max = 0.001212
# bert.encoder.layer.3.attention.output.LayerNorm.bias: grad min = -0.000968, grad max = 0.001130
# bert.encoder.layer.3.intermediate.dense.weight: grad min = -0.007966, grad max = 0.009053
# bert.encoder.layer.3.intermediate.dense.bias: grad min = -0.000560, grad max = 0.000738
# bert.encoder.layer.3.output.dense.weight: grad min = -0.001605, grad max = 0.001518
# bert.encoder.layer.3.output.dense.bias: grad min = -0.000914, grad max = 0.001201
# bert.encoder.layer.3.output.LayerNorm.weight: grad min = -0.002334, grad max = 0.004431
# bert.encoder.layer.3.output.LayerNorm.bias: grad min = -0.001411, grad max = 0.001536
# bert.encoder.layer.4.attention.self.query.weight: grad min = -0.001548, grad max = 0.001738
# bert.encoder.layer.4.attention.self.query.bias: grad min = -0.000206, grad max = 0.000240
# bert.encoder.layer.4.attention.self.key.weight: grad min = -0.001651, grad max = 0.001884
# bert.encoder.layer.4.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.4.attention.self.value.weight: grad min = -0.005482, grad max = 0.005446
# bert.encoder.layer.4.attention.self.value.bias: grad min = -0.001129, grad max = 0.001069
# bert.encoder.layer.4.attention.output.dense.weight: grad min = -0.002490, grad max = 0.002655
# bert.encoder.layer.4.attention.output.dense.bias: grad min = -0.001126, grad max = 0.002502
# bert.encoder.layer.4.attention.output.LayerNorm.weight: grad min = -0.001073, grad max = 0.001399
# bert.encoder.layer.4.attention.output.LayerNorm.bias: grad min = -0.001014, grad max = 0.001383
# bert.encoder.layer.4.intermediate.dense.weight: grad min = -0.012555, grad max = 0.023364
# bert.encoder.layer.4.intermediate.dense.bias: grad min = -0.000719, grad max = 0.000596
# bert.encoder.layer.4.output.dense.weight: grad min = -0.001424, grad max = 0.001539
# bert.encoder.layer.4.output.dense.bias: grad min = -0.001159, grad max = 0.001246
# bert.encoder.layer.4.output.LayerNorm.weight: grad min = -0.020060, grad max = 0.002685
# bert.encoder.layer.4.output.LayerNorm.bias: grad min = -0.001768, grad max = 0.001405
# bert.encoder.layer.5.attention.self.query.weight: grad min = -0.002352, grad max = 0.002225
# bert.encoder.layer.5.attention.self.query.bias: grad min = -0.000227, grad max = 0.000377
# bert.encoder.layer.5.attention.self.key.weight: grad min = -0.002536, grad max = 0.002285
# bert.encoder.layer.5.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.5.attention.self.value.weight: grad min = -0.006078, grad max = 0.007409
# bert.encoder.layer.5.attention.self.value.bias: grad min = -0.001315, grad max = 0.000819
# bert.encoder.layer.5.attention.output.dense.weight: grad min = -0.001060, grad max = 0.001196
# bert.encoder.layer.5.attention.output.dense.bias: grad min = -0.001557, grad max = 0.001251
# bert.encoder.layer.5.attention.output.LayerNorm.weight: grad min = -0.001242, grad max = 0.002399
# bert.encoder.layer.5.attention.output.LayerNorm.bias: grad min = -0.001385, grad max = 0.001219
# bert.encoder.layer.5.intermediate.dense.weight: grad min = -0.007719, grad max = 0.007147
# bert.encoder.layer.5.intermediate.dense.bias: grad min = -0.000634, grad max = 0.000606
# bert.encoder.layer.5.output.dense.weight: grad min = -0.001440, grad max = 0.001454
# bert.encoder.layer.5.output.dense.bias: grad min = -0.001409, grad max = 0.001242
# bert.encoder.layer.5.output.LayerNorm.weight: grad min = -0.002706, grad max = 0.003279
# bert.encoder.layer.5.output.LayerNorm.bias: grad min = -0.001934, grad max = 0.001620
# bert.encoder.layer.6.attention.self.query.weight: grad min = -0.002426, grad max = 0.002649
# bert.encoder.layer.6.attention.self.query.bias: grad min = -0.000351, grad max = 0.000347
# bert.encoder.layer.6.attention.self.key.weight: grad min = -0.002647, grad max = 0.001505
# bert.encoder.layer.6.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.6.attention.self.value.weight: grad min = -0.007046, grad max = 0.008326
# bert.encoder.layer.6.attention.self.value.bias: grad min = -0.001016, grad max = 0.000845
# bert.encoder.layer.6.attention.output.dense.weight: grad min = -0.001012, grad max = 0.000982
# bert.encoder.layer.6.attention.output.dense.bias: grad min = -0.001360, grad max = 0.001382
# bert.encoder.layer.6.attention.output.LayerNorm.weight: grad min = -0.001367, grad max = 0.001498
# bert.encoder.layer.6.attention.output.LayerNorm.bias: grad min = -0.001350, grad max = 0.001198
# bert.encoder.layer.6.intermediate.dense.weight: grad min = -0.014775, grad max = 0.006882
# bert.encoder.layer.6.intermediate.dense.bias: grad min = -0.000760, grad max = 0.000765
# bert.encoder.layer.6.output.dense.weight: grad min = -0.001293, grad max = 0.001103
# bert.encoder.layer.6.output.dense.bias: grad min = -0.001188, grad max = 0.000899
# bert.encoder.layer.6.output.LayerNorm.weight: grad min = -0.001372, grad max = 0.007433
# bert.encoder.layer.6.output.LayerNorm.bias: grad min = -0.001552, grad max = 0.001393
# bert.encoder.layer.7.attention.self.query.weight: grad min = -0.001968, grad max = 0.000999
# bert.encoder.layer.7.attention.self.query.bias: grad min = -0.000227, grad max = 0.000585
# bert.encoder.layer.7.attention.self.key.weight: grad min = -0.002134, grad max = 0.002249
# bert.encoder.layer.7.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.7.attention.self.value.weight: grad min = -0.009560, grad max = 0.010466
# bert.encoder.layer.7.attention.self.value.bias: grad min = -0.001108, grad max = 0.000970
# bert.encoder.layer.7.attention.output.dense.weight: grad min = -0.000705, grad max = 0.000735
# bert.encoder.layer.7.attention.output.dense.bias: grad min = -0.001365, grad max = 0.001417
# bert.encoder.layer.7.attention.output.LayerNorm.weight: grad min = -0.001202, grad max = 0.001768
# bert.encoder.layer.7.attention.output.LayerNorm.bias: grad min = -0.001156, grad max = 0.001044
# bert.encoder.layer.7.intermediate.dense.weight: grad min = -0.012164, grad max = 0.015750
# bert.encoder.layer.7.intermediate.dense.bias: grad min = -0.001083, grad max = 0.000666
# bert.encoder.layer.7.output.dense.weight: grad min = -0.001390, grad max = 0.001414
# bert.encoder.layer.7.output.dense.bias: grad min = -0.001106, grad max = 0.001180
# bert.encoder.layer.7.output.LayerNorm.weight: grad min = -0.013098, grad max = 0.001867
# bert.encoder.layer.7.output.LayerNorm.bias: grad min = -0.001721, grad max = 0.001697
# bert.encoder.layer.8.attention.self.query.weight: grad min = -0.001861, grad max = 0.003190
# bert.encoder.layer.8.attention.self.query.bias: grad min = -0.000319, grad max = 0.000288
# bert.encoder.layer.8.attention.self.key.weight: grad min = -0.001885, grad max = 0.002129
# bert.encoder.layer.8.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.8.attention.self.value.weight: grad min = -0.008021, grad max = 0.009100
# bert.encoder.layer.8.attention.self.value.bias: grad min = -0.001292, grad max = 0.001291
# bert.encoder.layer.8.attention.output.dense.weight: grad min = -0.001240, grad max = 0.001709
# bert.encoder.layer.8.attention.output.dense.bias: grad min = -0.001832, grad max = 0.001391
# bert.encoder.layer.8.attention.output.LayerNorm.weight: grad min = -0.001188, grad max = 0.001560
# bert.encoder.layer.8.attention.output.LayerNorm.bias: grad min = -0.001294, grad max = 0.001170
# bert.encoder.layer.8.intermediate.dense.weight: grad min = -0.018133, grad max = 0.017432
# bert.encoder.layer.8.intermediate.dense.bias: grad min = -0.000863, grad max = 0.000651
# bert.encoder.layer.8.output.dense.weight: grad min = -0.001218, grad max = 0.001399
# bert.encoder.layer.8.output.dense.bias: grad min = -0.001230, grad max = 0.001085
# bert.encoder.layer.8.output.LayerNorm.weight: grad min = -0.030363, grad max = 0.001679
# bert.encoder.layer.8.output.LayerNorm.bias: grad min = -0.002282, grad max = 0.001408
# bert.encoder.layer.9.attention.self.query.weight: grad min = -0.001697, grad max = 0.001550
# bert.encoder.layer.9.attention.self.query.bias: grad min = -0.000785, grad max = 0.000515
# bert.encoder.layer.9.attention.self.key.weight: grad min = -0.002153, grad max = 0.002146
# bert.encoder.layer.9.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.9.attention.self.value.weight: grad min = -0.006116, grad max = 0.003760
# bert.encoder.layer.9.attention.self.value.bias: grad min = -0.001151, grad max = 0.001253
# bert.encoder.layer.9.attention.output.dense.weight: grad min = -0.001955, grad max = 0.001667
# bert.encoder.layer.9.attention.output.dense.bias: grad min = -0.000801, grad max = 0.001142
# bert.encoder.layer.9.attention.output.LayerNorm.weight: grad min = -0.000847, grad max = 0.003806
# bert.encoder.layer.9.attention.output.LayerNorm.bias: grad min = -0.000853, grad max = 0.001009
# bert.encoder.layer.9.intermediate.dense.weight: grad min = -0.012552, grad max = 0.007629
# bert.encoder.layer.9.intermediate.dense.bias: grad min = -0.000800, grad max = 0.001838
# bert.encoder.layer.9.output.dense.weight: grad min = -0.001366, grad max = 0.001687
# bert.encoder.layer.9.output.dense.bias: grad min = -0.000848, grad max = 0.000893
# bert.encoder.layer.9.output.LayerNorm.weight: grad min = -0.006643, grad max = 0.002345
# bert.encoder.layer.9.output.LayerNorm.bias: grad min = -0.001831, grad max = 0.001226
# bert.encoder.layer.10.attention.self.query.weight: grad min = -0.000966, grad max = 0.000905
# bert.encoder.layer.10.attention.self.query.bias: grad min = -0.000242, grad max = 0.000281
# bert.encoder.layer.10.attention.self.key.weight: grad min = -0.001014, grad max = 0.001107
# bert.encoder.layer.10.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.10.attention.self.value.weight: grad min = -0.002515, grad max = 0.002133
# bert.encoder.layer.10.attention.self.value.bias: grad min = -0.000751, grad max = 0.000906
# bert.encoder.layer.10.attention.output.dense.weight: grad min = -0.001649, grad max = 0.001937
# bert.encoder.layer.10.attention.output.dense.bias: grad min = -0.000724, grad max = 0.000817
# bert.encoder.layer.10.attention.output.LayerNorm.weight: grad min = -0.000981, grad max = 0.002686
# bert.encoder.layer.10.attention.output.LayerNorm.bias: grad min = -0.001044, grad max = 0.000692
# bert.encoder.layer.10.intermediate.dense.weight: grad min = -0.007952, grad max = 0.016676
# bert.encoder.layer.10.intermediate.dense.bias: grad min = -0.000918, grad max = 0.001186
# bert.encoder.layer.10.output.dense.weight: grad min = -0.001920, grad max = 0.001255
# bert.encoder.layer.10.output.dense.bias: grad min = -0.000977, grad max = 0.000713
# bert.encoder.layer.10.output.LayerNorm.weight: grad min = -0.000928, grad max = 0.001605
# bert.encoder.layer.10.output.LayerNorm.bias: grad min = -0.000996, grad max = 0.000969
# bert.encoder.layer.11.attention.self.query.weight: grad min = -0.000547, grad max = 0.000352
# bert.encoder.layer.11.attention.self.query.bias: grad min = -0.000136, grad max = 0.000164
# bert.encoder.layer.11.attention.self.key.weight: grad min = -0.000561, grad max = 0.000691
# bert.encoder.layer.11.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.11.attention.self.value.weight: grad min = -0.007655, grad max = 0.004626
# bert.encoder.layer.11.attention.self.value.bias: grad min = -0.001177, grad max = 0.001507
# bert.encoder.layer.11.attention.output.dense.weight: grad min = -0.001312, grad max = 0.001201
# bert.encoder.layer.11.attention.output.dense.bias: grad min = -0.000498, grad max = 0.000491
# bert.encoder.layer.11.attention.output.LayerNorm.weight: grad min = -0.000721, grad max = 0.000729
# bert.encoder.layer.11.attention.output.LayerNorm.bias: grad min = -0.000563, grad max = 0.000554
# bert.encoder.layer.11.intermediate.dense.weight: grad min = -0.001475, grad max = 0.001653
# bert.encoder.layer.11.intermediate.dense.bias: grad min = -0.000456, grad max = 0.000568
# bert.encoder.layer.11.output.dense.weight: grad min = -0.001521, grad max = 0.001320
# bert.encoder.layer.11.output.dense.bias: grad min = -0.000465, grad max = 0.000341
# bert.encoder.layer.11.output.LayerNorm.weight: grad min = -0.001415, grad max = 0.000703
# bert.encoder.layer.11.output.LayerNorm.bias: grad min = -0.000830, grad max = 0.000727
# bert.pooler.dense.weight: grad min = -0.000936, grad max = 0.001067
# bert.pooler.dense.bias: grad min = -0.000567, grad max = 0.000491
# classifier.weight: grad min = -0.019980, grad max = 0.019595
# classifier.bias: grad min = -0.005582, grad max = 0.002860
# Epoch 3 Loss: 0.1536
#
# Macro F1 Score (binary multi-label): 0.9466
#
# Classification Report:
#                     precision    recall  f1-score   support
#
# gameplay_mechanics       0.98      0.96      0.97      5043
#     visual_quality       0.99      0.89      0.94      2601
#        story_depth       0.94      0.90      0.92      2884
#  pricing_and_value       0.96      0.97      0.96      3546
# bugs_and_stability       0.95      0.93      0.94      2560
#
#          micro avg       0.97      0.94      0.95     16634
#          macro avg       0.96      0.93      0.95     16634
#       weighted avg       0.97      0.94      0.95     16634
#        samples avg       0.92      0.90      0.90     16634
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in samples with no true nor predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
#torch.save(model.state_dict(), "Class_Assigner.pt")
#print("✅ Model state saved to: Class_Assigner.pt")
# Out:
# ✅ Model state saved to: Class_Assigner.pt

# %%
model = BertBinaryMultiLabelClassifier(num_labels=5)
model.load_state_dict(torch.load("C:/Users/ASUS/Desktop/University/second semester 2025 (END)/Capstone2/Class_Assigner.pt", map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
model.to(device)
model.eval()
print("✅ Mention Model Loaded...")
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_21072\2642342433.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("C:/Users/ASUS/Desktop/University/second semester 2025 (END)/Capstone2/Class_Assigner.pt", map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
# ✅ Mention Model Loaded...

# %%
#client = openai.OpenAI(api_key= API)  # use your real key

def speller(user_review):
    system_prompt = """
You are a gamer who fixes spelling in reviews and follows the rules below. Return only the corrected review.

EXAMPLES:
Input: grafix is amazing
Corrected: graphics is amazing

Input: storii was boring but coope was fun
Corrected: story was boring but co-op was fun

Input: grameplay has glithces and chaters
Corrected: gameplay has glitches and cheaters

Input: fpss drop is bad and bgs
Corrected: fps drop is bad and bugs

IMPORTANT RULES:
1. If the word 'storyline' appears (or any variation like 'storyine'), always change it to 'story').
2. If the word 'glitches' appears, always change it to glitch.
3. If the word 'textures' appears, always change it to texture.

ONLY return the corrected review. No explanation.
"""

    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_review}
        ],
        temperature=0,
        max_tokens=150
    )
    return response.choices[0].message.content.strip()

user_review = "now i do understand why the fuck people was mad at the end of the game, like actually what in the hell was that ending?"
print("Original:", user_review)
print("Corrected:", speller(user_review))
# Out:
# Original: now i do understand why the fuck people was mad at the end of the game, like actually what in the hell was that ending?
# Corrected: now I do understand why the fuck people were mad at the end of the game, like actually what in the hell was that ending?

# %%
model.eval()

label_columns = ["gameplay_mechanics", "visual_quality", "story_depth","pricing_and_value", "bugs_and_stability", "user_suggestion"]

def classify_review(text, threshold=0.5):
    text =  str(text).replace('&gt', '').replace('\n', ' ').strip().lower()
    text = speller(text)
    encoded = tokenizer(
        text,
        truncation=True,
        padding="max_length",
        max_length=256,
        return_tensors="pt"
    )

    input_ids = encoded['input_ids'].to(device)
    attention_mask = encoded['attention_mask'].to(device)

    with torch.no_grad():
        logits = model(input_ids=input_ids, attention_mask=attention_mask)
        probs = torch.sigmoid(logits).cpu().numpy()[0]

    results = {}
    for i, prob in enumerate(probs):
        results[label_columns[i]] = (int(prob >= threshold), round(prob, 3))

    print("\nPrediction (1 = mentioned, 0 = not):")
    for label, (pred, score) in results.items():
        print(f"{label:25}: {pred}  (confidence: {score:.3f})")

classify_review("This game will reward you with a high trust factor even after thousands of hours spent queueing with friends and playing fair — so now you'll enjoy matches with equally fair, skilled, and communicative teammates as a reward for your dedication. The best part is how smooth and consistent the experience feels, even when things get tense. If you can appreciate occasional bugs or quirks without letting them ruin the fun: absolutely give it a try. As a game, it's brilliantly crafted and incredibly addictive. While no system is perfect (some minor matchmaking inconsistencies or rare bugs), it still earns my full recommendation — both for casual players and competitive enthusiasts.")
# Out:
# Prediction (1 = mentioned, 0 = not):
# gameplay_mechanics       : 1  (confidence: 0.996)

# %% [markdown]
# ### Sentiment Overall Analysis

# %%
df = pd.read_csv("/content/train.csv")
X = df["user_review"]
y = df["user_suggestion"].tolist()

# %%
X = X.apply(preprocess_text)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.15, random_state=0)

train_encodings = tokenizer(X_train.tolist(), truncation=True, padding="max_length", max_length=256, return_tensors="pt")
val_encodings = tokenizer(X_val.tolist(), truncation=True, padding="max_length", max_length=256, return_tensors="pt")

train_dataset = TensorDataset(train_encodings['input_ids'],train_encodings['attention_mask'],torch.tensor(y_train).float().view(-1, 1))
val_dataset = TensorDataset(val_encodings['input_ids'],val_encodings['attention_mask'],torch.tensor(y_val).float().view(-1, 1))

train_loader = DataLoader(train_dataset, sampler=RandomSampler(train_dataset), batch_size=32)
val_loader = DataLoader(val_dataset, sampler=SequentialSampler(val_dataset), batch_size=32)

model = BertBinaryMultiLabelClassifier(num_labels=1).to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=2e-5)
loss_fn = nn.BCEWithLogitsLoss()

#clip_value = 50.0
epochs = 2
for epoch in range(epochs):
    model.train()
    total_loss = 0
    for step, batch in enumerate(train_loader):
        b_input_ids, b_input_mask, b_labels = [b.to(device) for b in batch]
        model.zero_grad()
        logits = model(b_input_ids, b_input_mask)
        loss = loss_fn(logits, b_labels.float())
        loss.backward()

        if step % 50 == 0:
            print(f"\n--- Gradient Report at Step {step}, Epoch {epoch+1} ---")
            for name, param in model.named_parameters():
                if param.requires_grad and param.grad is not None:
                    print(f"{name}: grad min = {param.grad.min():.6f}, grad max = {param.grad.max():.6f}")

        #clip_grad_norm_(model.parameters(), clip_value)
        optimizer.step()
        total_loss += loss.item()

    print(f"Epoch {epoch+1} Loss: {total_loss / len(train_loader):.4f}")

model.eval()
predictions, true_labels = [], []

with torch.no_grad():
    for batch in val_loader:
        b_input_ids, b_input_mask, b_labels = [b.to(device) for b in batch]
        logits = model(b_input_ids, b_input_mask)
        probs = torch.sigmoid(logits).cpu().numpy()
        predictions.extend(probs)
        true_labels.extend(b_labels.cpu().numpy())

pred_array = np.array(predictions)
pred_labels = (pred_array >= 0.5).astype(int)
true_labels = np.array(true_labels)

f1 = f1_score(true_labels, pred_labels)
print("\n F1 Score:", round(f1, 4))
print("\nClassification Report:")
print(classification_report(true_labels, pred_labels))
# Out:
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# --- Gradient Report at Step 0, Epoch 1 ---
# bert.embeddings.word_embeddings.weight: grad min = -0.010083, grad max = 0.008088
# bert.embeddings.position_embeddings.weight: grad min = -0.007905, grad max = 0.006482
# bert.embeddings.token_type_embeddings.weight: grad min = -0.043356, grad max = 0.050525
# bert.embeddings.LayerNorm.weight: grad min = -0.009820, grad max = 0.004467
# bert.embeddings.LayerNorm.bias: grad min = -0.002695, grad max = 0.003100
# bert.encoder.layer.0.attention.self.query.weight: grad min = -0.003737, grad max = 0.004054
# bert.encoder.layer.0.attention.self.query.bias: grad min = -0.000776, grad max = 0.000616
# bert.encoder.layer.0.attention.self.key.weight: grad min = -0.002317, grad max = 0.002978
# bert.encoder.layer.0.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.0.attention.self.value.weight: grad min = -0.005181, grad max = 0.006767
# bert.encoder.layer.0.attention.self.value.bias: grad min = -0.002481, grad max = 0.003607
# bert.encoder.layer.0.attention.output.dense.weight: grad min = -0.001715, grad max = 0.001481
# bert.encoder.layer.0.attention.output.dense.bias: grad min = -0.002009, grad max = 0.002418
# bert.encoder.layer.0.attention.output.LayerNorm.weight: grad min = -0.001892, grad max = 0.001344
# bert.encoder.layer.0.attention.output.LayerNorm.bias: grad min = -0.001385, grad max = 0.001641
# bert.encoder.layer.0.intermediate.dense.weight: grad min = -0.018098, grad max = 0.067498
# bert.encoder.layer.0.intermediate.dense.bias: grad min = -0.001482, grad max = 0.001243
# bert.encoder.layer.0.output.dense.weight: grad min = -0.003226, grad max = 0.003946
# bert.encoder.layer.0.output.dense.bias: grad min = -0.001416, grad max = 0.001428
# bert.encoder.layer.0.output.LayerNorm.weight: grad min = -0.016020, grad max = 0.014692
# bert.encoder.layer.0.output.LayerNorm.bias: grad min = -0.002644, grad max = 0.002812
# bert.encoder.layer.1.attention.self.query.weight: grad min = -0.003428, grad max = 0.002631
# bert.encoder.layer.1.attention.self.query.bias: grad min = -0.000570, grad max = 0.001033
# bert.encoder.layer.1.attention.self.key.weight: grad min = -0.008207, grad max = 0.002136
# bert.encoder.layer.1.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.1.attention.self.value.weight: grad min = -0.012530, grad max = 0.016852
# bert.encoder.layer.1.attention.self.value.bias: grad min = -0.003895, grad max = 0.002222
# bert.encoder.layer.1.attention.output.dense.weight: grad min = -0.002740, grad max = 0.002525
# bert.encoder.layer.1.attention.output.dense.bias: grad min = -0.002329, grad max = 0.002481
# bert.encoder.layer.1.attention.output.LayerNorm.weight: grad min = -0.002034, grad max = 0.001476
# bert.encoder.layer.1.attention.output.LayerNorm.bias: grad min = -0.001770, grad max = 0.001783
# bert.encoder.layer.1.intermediate.dense.weight: grad min = -0.021483, grad max = 0.059780
# bert.encoder.layer.1.intermediate.dense.bias: grad min = -0.004617, grad max = 0.000745
# bert.encoder.layer.1.output.dense.weight: grad min = -0.003533, grad max = 0.003282
# bert.encoder.layer.1.output.dense.bias: grad min = -0.002059, grad max = 0.001864
# bert.encoder.layer.1.output.LayerNorm.weight: grad min = -0.001557, grad max = 0.004369
# bert.encoder.layer.1.output.LayerNorm.bias: grad min = -0.002699, grad max = 0.002426
# bert.encoder.layer.2.attention.self.query.weight: grad min = -0.007084, grad max = 0.007606
# bert.encoder.layer.2.attention.self.query.bias: grad min = -0.001109, grad max = 0.001210
# bert.encoder.layer.2.attention.self.key.weight: grad min = -0.003846, grad max = 0.002188
# bert.encoder.layer.2.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.2.attention.self.value.weight: grad min = -0.018672, grad max = 0.013874
# bert.encoder.layer.2.attention.self.value.bias: grad min = -0.001859, grad max = 0.002970
# bert.encoder.layer.2.attention.output.dense.weight: grad min = -0.002907, grad max = 0.002892
# bert.encoder.layer.2.attention.output.dense.bias: grad min = -0.002468, grad max = 0.002381
# bert.encoder.layer.2.attention.output.LayerNorm.weight: grad min = -0.002658, grad max = 0.002190
# bert.encoder.layer.2.attention.output.LayerNorm.bias: grad min = -0.002134, grad max = 0.002033
# bert.encoder.layer.2.intermediate.dense.weight: grad min = -0.056556, grad max = 0.029227
# bert.encoder.layer.2.intermediate.dense.bias: grad min = -0.001678, grad max = 0.001444
# bert.encoder.layer.2.output.dense.weight: grad min = -0.003714, grad max = 0.002952
# bert.encoder.layer.2.output.dense.bias: grad min = -0.002280, grad max = 0.002111
# bert.encoder.layer.2.output.LayerNorm.weight: grad min = -0.003132, grad max = 0.003276
# bert.encoder.layer.2.output.LayerNorm.bias: grad min = -0.003282, grad max = 0.002967
# bert.encoder.layer.3.attention.self.query.weight: grad min = -0.005473, grad max = 0.004818
# bert.encoder.layer.3.attention.self.query.bias: grad min = -0.000809, grad max = 0.000635
# bert.encoder.layer.3.attention.self.key.weight: grad min = -0.003499, grad max = 0.003479
# bert.encoder.layer.3.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.3.attention.self.value.weight: grad min = -0.026709, grad max = 0.022458
# bert.encoder.layer.3.attention.self.value.bias: grad min = -0.003089, grad max = 0.003984
# bert.encoder.layer.3.attention.output.dense.weight: grad min = -0.004290, grad max = 0.003302
# bert.encoder.layer.3.attention.output.dense.bias: grad min = -0.003141, grad max = 0.002704
# bert.encoder.layer.3.attention.output.LayerNorm.weight: grad min = -0.005777, grad max = 0.001625
# bert.encoder.layer.3.attention.output.LayerNorm.bias: grad min = -0.002928, grad max = 0.002452
# bert.encoder.layer.3.intermediate.dense.weight: grad min = -0.049098, grad max = 0.062732
# bert.encoder.layer.3.intermediate.dense.bias: grad min = -0.002718, grad max = 0.001126
# bert.encoder.layer.3.output.dense.weight: grad min = -0.004378, grad max = 0.005426
# bert.encoder.layer.3.output.dense.bias: grad min = -0.002496, grad max = 0.002350
# bert.encoder.layer.3.output.LayerNorm.weight: grad min = -0.010099, grad max = 0.003790
# bert.encoder.layer.3.output.LayerNorm.bias: grad min = -0.004963, grad max = 0.003938
# bert.encoder.layer.4.attention.self.query.weight: grad min = -0.007305, grad max = 0.007896
# bert.encoder.layer.4.attention.self.query.bias: grad min = -0.001129, grad max = 0.000862
# bert.encoder.layer.4.attention.self.key.weight: grad min = -0.005956, grad max = 0.005532
# bert.encoder.layer.4.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.4.attention.self.value.weight: grad min = -0.039056, grad max = 0.017661
# bert.encoder.layer.4.attention.self.value.bias: grad min = -0.003116, grad max = 0.005569
# bert.encoder.layer.4.attention.output.dense.weight: grad min = -0.003740, grad max = 0.002987
# bert.encoder.layer.4.attention.output.dense.bias: grad min = -0.003584, grad max = 0.003090
# bert.encoder.layer.4.attention.output.LayerNorm.weight: grad min = -0.004456, grad max = 0.002174
# bert.encoder.layer.4.attention.output.LayerNorm.bias: grad min = -0.002572, grad max = 0.002557
# bert.encoder.layer.4.intermediate.dense.weight: grad min = -0.039458, grad max = 0.025245
# bert.encoder.layer.4.intermediate.dense.bias: grad min = -0.001495, grad max = 0.001811
# bert.encoder.layer.4.output.dense.weight: grad min = -0.005427, grad max = 0.006066
# bert.encoder.layer.4.output.dense.bias: grad min = -0.002916, grad max = 0.002670
# bert.encoder.layer.4.output.LayerNorm.weight: grad min = -0.019213, grad max = 0.011913
# bert.encoder.layer.4.output.LayerNorm.bias: grad min = -0.003963, grad max = 0.004720
# bert.encoder.layer.5.attention.self.query.weight: grad min = -0.003991, grad max = 0.008378
# bert.encoder.layer.5.attention.self.query.bias: grad min = -0.000859, grad max = 0.000478
# bert.encoder.layer.5.attention.self.key.weight: grad min = -0.003559, grad max = 0.003017
# bert.encoder.layer.5.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.5.attention.self.value.weight: grad min = -0.018538, grad max = 0.017494
# bert.encoder.layer.5.attention.self.value.bias: grad min = -0.003004, grad max = 0.002800
# bert.encoder.layer.5.attention.output.dense.weight: grad min = -0.002828, grad max = 0.003200
# bert.encoder.layer.5.attention.output.dense.bias: grad min = -0.002942, grad max = 0.003086
# bert.encoder.layer.5.attention.output.LayerNorm.weight: grad min = -0.012645, grad max = 0.001792
# bert.encoder.layer.5.attention.output.LayerNorm.bias: grad min = -0.002764, grad max = 0.002673
# bert.encoder.layer.5.intermediate.dense.weight: grad min = -0.054064, grad max = 0.037780
# bert.encoder.layer.5.intermediate.dense.bias: grad min = -0.002222, grad max = 0.002322
# bert.encoder.layer.5.output.dense.weight: grad min = -0.003674, grad max = 0.003379
# bert.encoder.layer.5.output.dense.bias: grad min = -0.002785, grad max = 0.002552
# bert.encoder.layer.5.output.LayerNorm.weight: grad min = -0.026220, grad max = 0.009827
# bert.encoder.layer.5.output.LayerNorm.bias: grad min = -0.003876, grad max = 0.003998
# bert.encoder.layer.6.attention.self.query.weight: grad min = -0.008094, grad max = 0.007008
# bert.encoder.layer.6.attention.self.query.bias: grad min = -0.000754, grad max = 0.000849
# bert.encoder.layer.6.attention.self.key.weight: grad min = -0.004401, grad max = 0.005062
# bert.encoder.layer.6.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.6.attention.self.value.weight: grad min = -0.021941, grad max = 0.035137
# bert.encoder.layer.6.attention.self.value.bias: grad min = -0.004362, grad max = 0.002945
# bert.encoder.layer.6.attention.output.dense.weight: grad min = -0.002710, grad max = 0.002377
# bert.encoder.layer.6.attention.output.dense.bias: grad min = -0.003178, grad max = 0.003377
# bert.encoder.layer.6.attention.output.LayerNorm.weight: grad min = -0.009424, grad max = 0.001978
# bert.encoder.layer.6.attention.output.LayerNorm.bias: grad min = -0.002978, grad max = 0.003074
# bert.encoder.layer.6.intermediate.dense.weight: grad min = -0.123672, grad max = 0.024984
# bert.encoder.layer.6.intermediate.dense.bias: grad min = -0.001290, grad max = 0.001964
# bert.encoder.layer.6.output.dense.weight: grad min = -0.003922, grad max = 0.004802
# bert.encoder.layer.6.output.dense.bias: grad min = -0.002737, grad max = 0.003427
# bert.encoder.layer.6.output.LayerNorm.weight: grad min = -0.016131, grad max = 0.043539
# bert.encoder.layer.6.output.LayerNorm.bias: grad min = -0.004498, grad max = 0.006534
# bert.encoder.layer.7.attention.self.query.weight: grad min = -0.003271, grad max = 0.003812
# bert.encoder.layer.7.attention.self.query.bias: grad min = -0.000386, grad max = 0.000362
# bert.encoder.layer.7.attention.self.key.weight: grad min = -0.002762, grad max = 0.002827
# bert.encoder.layer.7.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.7.attention.self.value.weight: grad min = -0.029413, grad max = 0.026467
# bert.encoder.layer.7.attention.self.value.bias: grad min = -0.002815, grad max = 0.003826
# bert.encoder.layer.7.attention.output.dense.weight: grad min = -0.002657, grad max = 0.002981
# bert.encoder.layer.7.attention.output.dense.bias: grad min = -0.004700, grad max = 0.004132
# bert.encoder.layer.7.attention.output.LayerNorm.weight: grad min = -0.020593, grad max = 0.002407
# bert.encoder.layer.7.attention.output.LayerNorm.bias: grad min = -0.003471, grad max = 0.003486
# bert.encoder.layer.7.intermediate.dense.weight: grad min = -0.064522, grad max = 0.107970
# bert.encoder.layer.7.intermediate.dense.bias: grad min = -0.002239, grad max = 0.005694
# bert.encoder.layer.7.output.dense.weight: grad min = -0.009490, grad max = 0.009264
# bert.encoder.layer.7.output.dense.bias: grad min = -0.003309, grad max = 0.003345
# bert.encoder.layer.7.output.LayerNorm.weight: grad min = -0.018015, grad max = 0.036585
# bert.encoder.layer.7.output.LayerNorm.bias: grad min = -0.006977, grad max = 0.007362
# bert.encoder.layer.8.attention.self.query.weight: grad min = -0.018260, grad max = 0.018663
# bert.encoder.layer.8.attention.self.query.bias: grad min = -0.002073, grad max = 0.002047
# bert.encoder.layer.8.attention.self.key.weight: grad min = -0.005291, grad max = 0.005828
# bert.encoder.layer.8.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.8.attention.self.value.weight: grad min = -0.038356, grad max = 0.032070
# bert.encoder.layer.8.attention.self.value.bias: grad min = -0.004564, grad max = 0.006095
# bert.encoder.layer.8.attention.output.dense.weight: grad min = -0.004113, grad max = 0.005026
# bert.encoder.layer.8.attention.output.dense.bias: grad min = -0.005189, grad max = 0.004273
# bert.encoder.layer.8.attention.output.LayerNorm.weight: grad min = -0.042005, grad max = 0.003691
# bert.encoder.layer.8.attention.output.LayerNorm.bias: grad min = -0.004063, grad max = 0.004202
# bert.encoder.layer.8.intermediate.dense.weight: grad min = -0.072766, grad max = 0.239496
# bert.encoder.layer.8.intermediate.dense.bias: grad min = -0.003455, grad max = 0.002669
# bert.encoder.layer.8.output.dense.weight: grad min = -0.004839, grad max = 0.005866
# bert.encoder.layer.8.output.dense.bias: grad min = -0.003349, grad max = 0.004567
# bert.encoder.layer.8.output.LayerNorm.weight: grad min = -0.067499, grad max = 0.003565
# bert.encoder.layer.8.output.LayerNorm.bias: grad min = -0.005260, grad max = 0.006224
# bert.encoder.layer.9.attention.self.query.weight: grad min = -0.010412, grad max = 0.008947
# bert.encoder.layer.9.attention.self.query.bias: grad min = -0.001555, grad max = 0.001130
# bert.encoder.layer.9.attention.self.key.weight: grad min = -0.008095, grad max = 0.007324
# bert.encoder.layer.9.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.9.attention.self.value.weight: grad min = -0.054792, grad max = 0.055341
# bert.encoder.layer.9.attention.self.value.bias: grad min = -0.008758, grad max = 0.009304
# bert.encoder.layer.9.attention.output.dense.weight: grad min = -0.008034, grad max = 0.007536
# bert.encoder.layer.9.attention.output.dense.bias: grad min = -0.004329, grad max = 0.005035
# bert.encoder.layer.9.attention.output.LayerNorm.weight: grad min = -0.027773, grad max = 0.003283
# bert.encoder.layer.9.attention.output.LayerNorm.bias: grad min = -0.003809, grad max = 0.003997
# bert.encoder.layer.9.intermediate.dense.weight: grad min = -0.061413, grad max = 0.047377
# bert.encoder.layer.9.intermediate.dense.bias: grad min = -0.003397, grad max = 0.003966
# bert.encoder.layer.9.output.dense.weight: grad min = -0.009634, grad max = 0.014793
# bert.encoder.layer.9.output.dense.bias: grad min = -0.004352, grad max = 0.004535
# bert.encoder.layer.9.output.LayerNorm.weight: grad min = -0.052790, grad max = 0.004597
# bert.encoder.layer.9.output.LayerNorm.bias: grad min = -0.007584, grad max = 0.007190
# bert.encoder.layer.10.attention.self.query.weight: grad min = -0.011980, grad max = 0.013392
# bert.encoder.layer.10.attention.self.query.bias: grad min = -0.001579, grad max = 0.001324
# bert.encoder.layer.10.attention.self.key.weight: grad min = -0.009594, grad max = 0.012430
# bert.encoder.layer.10.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.10.attention.self.value.weight: grad min = -0.062050, grad max = 0.088367
# bert.encoder.layer.10.attention.self.value.bias: grad min = -0.020093, grad max = 0.013533
# bert.encoder.layer.10.attention.output.dense.weight: grad min = -0.006223, grad max = 0.005699
# bert.encoder.layer.10.attention.output.dense.bias: grad min = -0.004497, grad max = 0.004189
# bert.encoder.layer.10.attention.output.LayerNorm.weight: grad min = -0.034328, grad max = 0.003915
# bert.encoder.layer.10.attention.output.LayerNorm.bias: grad min = -0.004344, grad max = 0.004266
# bert.encoder.layer.10.intermediate.dense.weight: grad min = -0.095583, grad max = 0.200906
# bert.encoder.layer.10.intermediate.dense.bias: grad min = -0.011871, grad max = 0.006899
# bert.encoder.layer.10.output.dense.weight: grad min = -0.010934, grad max = 0.009917
# bert.encoder.layer.10.output.dense.bias: grad min = -0.003900, grad max = 0.004372
# bert.encoder.layer.10.output.LayerNorm.weight: grad min = -0.012298, grad max = 0.010480
# bert.encoder.layer.10.output.LayerNorm.bias: grad min = -0.006268, grad max = 0.006725
# bert.encoder.layer.11.attention.self.query.weight: grad min = -0.011214, grad max = 0.015136
# bert.encoder.layer.11.attention.self.query.bias: grad min = -0.002186, grad max = 0.001614
# bert.encoder.layer.11.attention.self.key.weight: grad min = -0.038982, grad max = 0.011931
# bert.encoder.layer.11.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.11.attention.self.value.weight: grad min = -0.095154, grad max = 0.085536
# bert.encoder.layer.11.attention.self.value.bias: grad min = -0.008326, grad max = 0.009799
# bert.encoder.layer.11.attention.output.dense.weight: grad min = -0.007019, grad max = 0.006050
# bert.encoder.layer.11.attention.output.dense.bias: grad min = -0.002928, grad max = 0.003622
# bert.encoder.layer.11.attention.output.LayerNorm.weight: grad min = -0.011677, grad max = 0.002585
# bert.encoder.layer.11.attention.output.LayerNorm.bias: grad min = -0.002164, grad max = 0.001979
# bert.encoder.layer.11.intermediate.dense.weight: grad min = -0.057914, grad max = 0.039047
# bert.encoder.layer.11.intermediate.dense.bias: grad min = -0.001840, grad max = 0.002869
# bert.encoder.layer.11.output.dense.weight: grad min = -0.007974, grad max = 0.007463
# bert.encoder.layer.11.output.dense.bias: grad min = -0.002204, grad max = 0.001975
# bert.encoder.layer.11.output.LayerNorm.weight: grad min = -0.005001, grad max = 0.007937
# bert.encoder.layer.11.output.LayerNorm.bias: grad min = -0.004465, grad max = 0.003936
# bert.pooler.dense.weight: grad min = -0.045484, grad max = 0.056721
# bert.pooler.dense.bias: grad min = -0.010685, grad max = 0.008711
# classifier.weight: grad min = -0.293381, grad max = 0.287060
# classifier.bias: grad min = -0.179233, grad max = -0.179233
#
# --- Gradient Report at Step 50, Epoch 1 ---
# bert.embeddings.word_embeddings.weight: grad min = -0.015564, grad max = 0.013558
# bert.embeddings.position_embeddings.weight: grad min = -0.014724, grad max = 0.015908
# bert.embeddings.token_type_embeddings.weight: grad min = -0.186442, grad max = 0.182171
# bert.embeddings.LayerNorm.weight: grad min = -0.008107, grad max = 0.028697
# bert.embeddings.LayerNorm.bias: grad min = -0.010893, grad max = 0.011177
# bert.encoder.layer.0.attention.self.query.weight: grad min = -0.006127, grad max = 0.011822
# bert.encoder.layer.0.attention.self.query.bias: grad min = -0.001546, grad max = 0.001571
# bert.encoder.layer.0.attention.self.key.weight: grad min = -0.002880, grad max = 0.002234
# bert.encoder.layer.0.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.0.attention.self.value.weight: grad min = -0.014360, grad max = 0.019920
# bert.encoder.layer.0.attention.self.value.bias: grad min = -0.011527, grad max = 0.006471
# bert.encoder.layer.0.attention.output.dense.weight: grad min = -0.006465, grad max = 0.007632
# bert.encoder.layer.0.attention.output.dense.bias: grad min = -0.006527, grad max = 0.005576
# bert.encoder.layer.0.attention.output.LayerNorm.weight: grad min = -0.003482, grad max = 0.002545
# bert.encoder.layer.0.attention.output.LayerNorm.bias: grad min = -0.005207, grad max = 0.004293
# bert.encoder.layer.0.intermediate.dense.weight: grad min = -0.057136, grad max = 0.059767
# bert.encoder.layer.0.intermediate.dense.bias: grad min = -0.003413, grad max = 0.002777
# bert.encoder.layer.0.output.dense.weight: grad min = -0.007217, grad max = 0.007428
# bert.encoder.layer.0.output.dense.bias: grad min = -0.005081, grad max = 0.004826
# bert.encoder.layer.0.output.LayerNorm.weight: grad min = -0.004944, grad max = 0.067581
# bert.encoder.layer.0.output.LayerNorm.bias: grad min = -0.008880, grad max = 0.007810
# bert.encoder.layer.1.attention.self.query.weight: grad min = -0.005871, grad max = 0.006700
# bert.encoder.layer.1.attention.self.query.bias: grad min = -0.001424, grad max = 0.001225
# bert.encoder.layer.1.attention.self.key.weight: grad min = -0.004017, grad max = 0.007373
# bert.encoder.layer.1.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.1.attention.self.value.weight: grad min = -0.029584, grad max = 0.047504
# bert.encoder.layer.1.attention.self.value.bias: grad min = -0.008964, grad max = 0.005262
# bert.encoder.layer.1.attention.output.dense.weight: grad min = -0.008616, grad max = 0.008260
# bert.encoder.layer.1.attention.output.dense.bias: grad min = -0.006767, grad max = 0.006196
# bert.encoder.layer.1.attention.output.LayerNorm.weight: grad min = -0.003945, grad max = 0.006280
# bert.encoder.layer.1.attention.output.LayerNorm.bias: grad min = -0.005908, grad max = 0.004620
# bert.encoder.layer.1.intermediate.dense.weight: grad min = -0.139774, grad max = 0.107701
# bert.encoder.layer.1.intermediate.dense.bias: grad min = -0.003851, grad max = 0.007651
# bert.encoder.layer.1.output.dense.weight: grad min = -0.006037, grad max = 0.005889
# bert.encoder.layer.1.output.dense.bias: grad min = -0.004891, grad max = 0.005185
# bert.encoder.layer.1.output.LayerNorm.weight: grad min = -0.005018, grad max = 0.084067
# bert.encoder.layer.1.output.LayerNorm.bias: grad min = -0.007134, grad max = 0.005651
# bert.encoder.layer.2.attention.self.query.weight: grad min = -0.017518, grad max = 0.014830
# bert.encoder.layer.2.attention.self.query.bias: grad min = -0.001678, grad max = 0.001950
# bert.encoder.layer.2.attention.self.key.weight: grad min = -0.004148, grad max = 0.006323
# bert.encoder.layer.2.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.2.attention.self.value.weight: grad min = -0.032020, grad max = 0.035138
# bert.encoder.layer.2.attention.self.value.bias: grad min = -0.004191, grad max = 0.005195
# bert.encoder.layer.2.attention.output.dense.weight: grad min = -0.007568, grad max = 0.007543
# bert.encoder.layer.2.attention.output.dense.bias: grad min = -0.006024, grad max = 0.005898
# bert.encoder.layer.2.attention.output.LayerNorm.weight: grad min = -0.004457, grad max = 0.010440
# bert.encoder.layer.2.attention.output.LayerNorm.bias: grad min = -0.006026, grad max = 0.005584
# bert.encoder.layer.2.intermediate.dense.weight: grad min = -0.058157, grad max = 0.057449
# bert.encoder.layer.2.intermediate.dense.bias: grad min = -0.004424, grad max = 0.003059
# bert.encoder.layer.2.output.dense.weight: grad min = -0.009858, grad max = 0.009406
# bert.encoder.layer.2.output.dense.bias: grad min = -0.006315, grad max = 0.005391
# bert.encoder.layer.2.output.LayerNorm.weight: grad min = -0.004542, grad max = 0.039360
# bert.encoder.layer.2.output.LayerNorm.bias: grad min = -0.008164, grad max = 0.009819
# bert.encoder.layer.3.attention.self.query.weight: grad min = -0.011636, grad max = 0.010239
# bert.encoder.layer.3.attention.self.query.bias: grad min = -0.001472, grad max = 0.001666
# bert.encoder.layer.3.attention.self.key.weight: grad min = -0.005282, grad max = 0.005397
# bert.encoder.layer.3.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.3.attention.self.value.weight: grad min = -0.064249, grad max = 0.059390
# bert.encoder.layer.3.attention.self.value.bias: grad min = -0.008367, grad max = 0.008579
# bert.encoder.layer.3.attention.output.dense.weight: grad min = -0.011569, grad max = 0.017332
# bert.encoder.layer.3.attention.output.dense.bias: grad min = -0.009173, grad max = 0.011385
# bert.encoder.layer.3.attention.output.LayerNorm.weight: grad min = -0.006447, grad max = 0.007567
# bert.encoder.layer.3.attention.output.LayerNorm.bias: grad min = -0.009324, grad max = 0.007866
# bert.encoder.layer.3.intermediate.dense.weight: grad min = -0.067526, grad max = 0.043545
# bert.encoder.layer.3.intermediate.dense.bias: grad min = -0.002694, grad max = 0.005012
# bert.encoder.layer.3.output.dense.weight: grad min = -0.009974, grad max = 0.008664
# bert.encoder.layer.3.output.dense.bias: grad min = -0.008859, grad max = 0.006840
# bert.encoder.layer.3.output.LayerNorm.weight: grad min = -0.007343, grad max = 0.112352
# bert.encoder.layer.3.output.LayerNorm.bias: grad min = -0.011698, grad max = 0.010304
# bert.encoder.layer.4.attention.self.query.weight: grad min = -0.010695, grad max = 0.012123
# bert.encoder.layer.4.attention.self.query.bias: grad min = -0.001937, grad max = 0.001810
# bert.encoder.layer.4.attention.self.key.weight: grad min = -0.012558, grad max = 0.011812
# bert.encoder.layer.4.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.4.attention.self.value.weight: grad min = -0.037302, grad max = 0.050789
# bert.encoder.layer.4.attention.self.value.bias: grad min = -0.011057, grad max = 0.009457
# bert.encoder.layer.4.attention.output.dense.weight: grad min = -0.009278, grad max = 0.007344
# bert.encoder.layer.4.attention.output.dense.bias: grad min = -0.009370, grad max = 0.007152
# bert.encoder.layer.4.attention.output.LayerNorm.weight: grad min = -0.005958, grad max = 0.008841
# bert.encoder.layer.4.attention.output.LayerNorm.bias: grad min = -0.008860, grad max = 0.007180
# bert.encoder.layer.4.intermediate.dense.weight: grad min = -0.100034, grad max = 0.144099
# bert.encoder.layer.4.intermediate.dense.bias: grad min = -0.009504, grad max = 0.002605
# bert.encoder.layer.4.output.dense.weight: grad min = -0.011905, grad max = 0.010027
# bert.encoder.layer.4.output.dense.bias: grad min = -0.010540, grad max = 0.007567
# bert.encoder.layer.4.output.LayerNorm.weight: grad min = -0.006904, grad max = 0.026994
# bert.encoder.layer.4.output.LayerNorm.bias: grad min = -0.012729, grad max = 0.010828
# bert.encoder.layer.5.attention.self.query.weight: grad min = -0.018862, grad max = 0.012145
# bert.encoder.layer.5.attention.self.query.bias: grad min = -0.001284, grad max = 0.001919
# bert.encoder.layer.5.attention.self.key.weight: grad min = -0.009094, grad max = 0.008027
# bert.encoder.layer.5.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.5.attention.self.value.weight: grad min = -0.044470, grad max = 0.051606
# bert.encoder.layer.5.attention.self.value.bias: grad min = -0.007765, grad max = 0.008262
# bert.encoder.layer.5.attention.output.dense.weight: grad min = -0.006850, grad max = 0.007834
# bert.encoder.layer.5.attention.output.dense.bias: grad min = -0.009734, grad max = 0.007971
# bert.encoder.layer.5.attention.output.LayerNorm.weight: grad min = -0.005151, grad max = 0.014385
# bert.encoder.layer.5.attention.output.LayerNorm.bias: grad min = -0.009850, grad max = 0.007252
# bert.encoder.layer.5.intermediate.dense.weight: grad min = -0.067160, grad max = 0.111035
# bert.encoder.layer.5.intermediate.dense.bias: grad min = -0.006974, grad max = 0.003932
# bert.encoder.layer.5.output.dense.weight: grad min = -0.006821, grad max = 0.007494
# bert.encoder.layer.5.output.dense.bias: grad min = -0.009059, grad max = 0.006952
# bert.encoder.layer.5.output.LayerNorm.weight: grad min = -0.057191, grad max = 0.023219
# bert.encoder.layer.5.output.LayerNorm.bias: grad min = -0.012503, grad max = 0.010572
# bert.encoder.layer.6.attention.self.query.weight: grad min = -0.010422, grad max = 0.015260
# bert.encoder.layer.6.attention.self.query.bias: grad min = -0.001851, grad max = 0.001477
# bert.encoder.layer.6.attention.self.key.weight: grad min = -0.013471, grad max = 0.011143
# bert.encoder.layer.6.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.6.attention.self.value.weight: grad min = -0.049984, grad max = 0.051308
# bert.encoder.layer.6.attention.self.value.bias: grad min = -0.006933, grad max = 0.007852
# bert.encoder.layer.6.attention.output.dense.weight: grad min = -0.011238, grad max = 0.011150
# bert.encoder.layer.6.attention.output.dense.bias: grad min = -0.010254, grad max = 0.009073
# bert.encoder.layer.6.attention.output.LayerNorm.weight: grad min = -0.007249, grad max = 0.013175
# bert.encoder.layer.6.attention.output.LayerNorm.bias: grad min = -0.010790, grad max = 0.010368
# bert.encoder.layer.6.intermediate.dense.weight: grad min = -0.092064, grad max = 0.079922
# bert.encoder.layer.6.intermediate.dense.bias: grad min = -0.005923, grad max = 0.008653
# bert.encoder.layer.6.output.dense.weight: grad min = -0.011519, grad max = 0.010812
# bert.encoder.layer.6.output.dense.bias: grad min = -0.010165, grad max = 0.010313
# bert.encoder.layer.6.output.LayerNorm.weight: grad min = -0.046220, grad max = 0.027464
# bert.encoder.layer.6.output.LayerNorm.bias: grad min = -0.014772, grad max = 0.014681
# bert.encoder.layer.7.attention.self.query.weight: grad min = -0.007789, grad max = 0.009017
# bert.encoder.layer.7.attention.self.query.bias: grad min = -0.001239, grad max = 0.001136
# bert.encoder.layer.7.attention.self.key.weight: grad min = -0.008091, grad max = 0.004978
# bert.encoder.layer.7.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.7.attention.self.value.weight: grad min = -0.049170, grad max = 0.054243
# bert.encoder.layer.7.attention.self.value.bias: grad min = -0.006728, grad max = 0.008410
# bert.encoder.layer.7.attention.output.dense.weight: grad min = -0.008158, grad max = 0.007320
# bert.encoder.layer.7.attention.output.dense.bias: grad min = -0.009971, grad max = 0.009236
# bert.encoder.layer.7.attention.output.LayerNorm.weight: grad min = -0.010179, grad max = 0.013056
# bert.encoder.layer.7.attention.output.LayerNorm.bias: grad min = -0.010510, grad max = 0.010360
# bert.encoder.layer.7.intermediate.dense.weight: grad min = -0.200349, grad max = 0.178817
# bert.encoder.layer.7.intermediate.dense.bias: grad min = -0.016076, grad max = 0.012759
# bert.encoder.layer.7.output.dense.weight: grad min = -0.007804, grad max = 0.009221
# bert.encoder.layer.7.output.dense.bias: grad min = -0.009550, grad max = 0.009202
# bert.encoder.layer.7.output.LayerNorm.weight: grad min = -0.057956, grad max = 0.007927
# bert.encoder.layer.7.output.LayerNorm.bias: grad min = -0.014954, grad max = 0.012873
# bert.encoder.layer.8.attention.self.query.weight: grad min = -0.020027, grad max = 0.020008
# bert.encoder.layer.8.attention.self.query.bias: grad min = -0.002882, grad max = 0.002708
# bert.encoder.layer.8.attention.self.key.weight: grad min = -0.007225, grad max = 0.008233
# bert.encoder.layer.8.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.8.attention.self.value.weight: grad min = -0.051326, grad max = 0.055056
# bert.encoder.layer.8.attention.self.value.bias: grad min = -0.010019, grad max = 0.010394
# bert.encoder.layer.8.attention.output.dense.weight: grad min = -0.010468, grad max = 0.008681
# bert.encoder.layer.8.attention.output.dense.bias: grad min = -0.006943, grad max = 0.007646
# bert.encoder.layer.8.attention.output.LayerNorm.weight: grad min = -0.010742, grad max = 0.010217
# bert.encoder.layer.8.attention.output.LayerNorm.bias: grad min = -0.006703, grad max = 0.007735
# bert.encoder.layer.8.intermediate.dense.weight: grad min = -0.160405, grad max = 0.114590
# bert.encoder.layer.8.intermediate.dense.bias: grad min = -0.007444, grad max = 0.013530
# bert.encoder.layer.8.output.dense.weight: grad min = -0.013436, grad max = 0.013557
# bert.encoder.layer.8.output.dense.bias: grad min = -0.004895, grad max = 0.005511
# bert.encoder.layer.8.output.LayerNorm.weight: grad min = -0.006607, grad max = 0.007530
# bert.encoder.layer.8.output.LayerNorm.bias: grad min = -0.007333, grad max = 0.007846
# bert.encoder.layer.9.attention.self.query.weight: grad min = -0.040291, grad max = 0.033291
# bert.encoder.layer.9.attention.self.query.bias: grad min = -0.005469, grad max = 0.006597
# bert.encoder.layer.9.attention.self.key.weight: grad min = -0.009200, grad max = 0.011299
# bert.encoder.layer.9.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.9.attention.self.value.weight: grad min = -0.031029, grad max = 0.035912
# bert.encoder.layer.9.attention.self.value.bias: grad min = -0.006167, grad max = 0.006555
# bert.encoder.layer.9.attention.output.dense.weight: grad min = -0.007509, grad max = 0.007526
# bert.encoder.layer.9.attention.output.dense.bias: grad min = -0.003574, grad max = 0.003674
# bert.encoder.layer.9.attention.output.LayerNorm.weight: grad min = -0.003574, grad max = 0.005786
# bert.encoder.layer.9.attention.output.LayerNorm.bias: grad min = -0.003685, grad max = 0.004392
# bert.encoder.layer.9.intermediate.dense.weight: grad min = -0.062601, grad max = 0.030027
# bert.encoder.layer.9.intermediate.dense.bias: grad min = -0.002556, grad max = 0.006373
# bert.encoder.layer.9.output.dense.weight: grad min = -0.007478, grad max = 0.007278
# bert.encoder.layer.9.output.dense.bias: grad min = -0.003395, grad max = 0.003657
# bert.encoder.layer.9.output.LayerNorm.weight: grad min = -0.075704, grad max = 0.004482
# bert.encoder.layer.9.output.LayerNorm.bias: grad min = -0.005888, grad max = 0.004993
# bert.encoder.layer.10.attention.self.query.weight: grad min = -0.012780, grad max = 0.006568
# bert.encoder.layer.10.attention.self.query.bias: grad min = -0.000978, grad max = 0.001636
# bert.encoder.layer.10.attention.self.key.weight: grad min = -0.005583, grad max = 0.011157
# bert.encoder.layer.10.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.10.attention.self.value.weight: grad min = -0.026689, grad max = 0.040081
# bert.encoder.layer.10.attention.self.value.bias: grad min = -0.010739, grad max = 0.007690
# bert.encoder.layer.10.attention.output.dense.weight: grad min = -0.004125, grad max = 0.003214
# bert.encoder.layer.10.attention.output.dense.bias: grad min = -0.002945, grad max = 0.002666
# bert.encoder.layer.10.attention.output.LayerNorm.weight: grad min = -0.003424, grad max = 0.011417
# bert.encoder.layer.10.attention.output.LayerNorm.bias: grad min = -0.002811, grad max = 0.002545
# bert.encoder.layer.10.intermediate.dense.weight: grad min = -0.042202, grad max = 0.054865
# bert.encoder.layer.10.intermediate.dense.bias: grad min = -0.009030, grad max = 0.004546
# bert.encoder.layer.10.output.dense.weight: grad min = -0.004277, grad max = 0.005221
# bert.encoder.layer.10.output.dense.bias: grad min = -0.002533, grad max = 0.001963
# bert.encoder.layer.10.output.LayerNorm.weight: grad min = -0.002922, grad max = 0.011656
# bert.encoder.layer.10.output.LayerNorm.bias: grad min = -0.003474, grad max = 0.002790
# bert.encoder.layer.11.attention.self.query.weight: grad min = -0.008245, grad max = 0.008953
# bert.encoder.layer.11.attention.self.query.bias: grad min = -0.001418, grad max = 0.001152
# bert.encoder.layer.11.attention.self.key.weight: grad min = -0.002961, grad max = 0.004312
# bert.encoder.layer.11.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.11.attention.self.value.weight: grad min = -0.045115, grad max = 0.024810
# bert.encoder.layer.11.attention.self.value.bias: grad min = -0.003442, grad max = 0.005249
# bert.encoder.layer.11.attention.output.dense.weight: grad min = -0.003359, grad max = 0.002944
# bert.encoder.layer.11.attention.output.dense.bias: grad min = -0.001676, grad max = 0.001500
# bert.encoder.layer.11.attention.output.LayerNorm.weight: grad min = -0.001965, grad max = 0.003330
# bert.encoder.layer.11.attention.output.LayerNorm.bias: grad min = -0.001246, grad max = 0.001027
# bert.encoder.layer.11.intermediate.dense.weight: grad min = -0.019526, grad max = 0.035034
# bert.encoder.layer.11.intermediate.dense.bias: grad min = -0.002485, grad max = 0.001407
# bert.encoder.layer.11.output.dense.weight: grad min = -0.002713, grad max = 0.003195
# bert.encoder.layer.11.output.dense.bias: grad min = -0.000959, grad max = 0.000775
# bert.encoder.layer.11.output.LayerNorm.weight: grad min = -0.001523, grad max = 0.011091
# bert.encoder.layer.11.output.LayerNorm.bias: grad min = -0.001100, grad max = 0.000876
# bert.pooler.dense.weight: grad min = -0.012052, grad max = 0.011255
# bert.pooler.dense.bias: grad min = -0.003695, grad max = 0.004117
# classifier.weight: grad min = -0.103374, grad max = 0.145907
# classifier.bias: grad min = 0.045952, grad max = 0.045952
#
# --- Gradient Report at Step 100, Epoch 1 ---
# bert.embeddings.word_embeddings.weight: grad min = -0.242433, grad max = 0.176446
# bert.embeddings.position_embeddings.weight: grad min = -0.242971, grad max = 0.176894
# bert.embeddings.token_type_embeddings.weight: grad min = -0.393630, grad max = 0.370714
# bert.embeddings.LayerNorm.weight: grad min = -0.015218, grad max = 0.057611
# bert.embeddings.LayerNorm.bias: grad min = -0.025227, grad max = 0.022816
# bert.encoder.layer.0.attention.self.query.weight: grad min = -0.005906, grad max = 0.008234
# bert.encoder.layer.0.attention.self.query.bias: grad min = -0.002582, grad max = 0.002668
# bert.encoder.layer.0.attention.self.key.weight: grad min = -0.011584, grad max = 0.008132
# bert.encoder.layer.0.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.0.attention.self.value.weight: grad min = -0.069298, grad max = 0.062586
# bert.encoder.layer.0.attention.self.value.bias: grad min = -0.015999, grad max = 0.013845
# bert.encoder.layer.0.attention.output.dense.weight: grad min = -0.014041, grad max = 0.013775
# bert.encoder.layer.0.attention.output.dense.bias: grad min = -0.013099, grad max = 0.013211
# bert.encoder.layer.0.attention.output.LayerNorm.weight: grad min = -0.010704, grad max = 0.012851
# bert.encoder.layer.0.attention.output.LayerNorm.bias: grad min = -0.009174, grad max = 0.008692
# bert.encoder.layer.0.intermediate.dense.weight: grad min = -0.140966, grad max = 0.084091
# bert.encoder.layer.0.intermediate.dense.bias: grad min = -0.005704, grad max = 0.006430
# bert.encoder.layer.0.output.dense.weight: grad min = -0.020874, grad max = 0.017722
# bert.encoder.layer.0.output.dense.bias: grad min = -0.009388, grad max = 0.008141
# bert.encoder.layer.0.output.LayerNorm.weight: grad min = -0.023448, grad max = 0.016194
# bert.encoder.layer.0.output.LayerNorm.bias: grad min = -0.013766, grad max = 0.011521
# bert.encoder.layer.1.attention.self.query.weight: grad min = -0.009961, grad max = 0.008048
# bert.encoder.layer.1.attention.self.query.bias: grad min = -0.001887, grad max = 0.002025
# bert.encoder.layer.1.attention.self.key.weight: grad min = -0.008734, grad max = 0.010085
# bert.encoder.layer.1.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.1.attention.self.value.weight: grad min = -0.082166, grad max = 0.055686
# bert.encoder.layer.1.attention.self.value.bias: grad min = -0.009560, grad max = 0.012702
# bert.encoder.layer.1.attention.output.dense.weight: grad min = -0.015200, grad max = 0.017397
# bert.encoder.layer.1.attention.output.dense.bias: grad min = -0.016069, grad max = 0.011649
# bert.encoder.layer.1.attention.output.LayerNorm.weight: grad min = -0.014046, grad max = 0.010961
# bert.encoder.layer.1.attention.output.LayerNorm.bias: grad min = -0.011229, grad max = 0.009129
# bert.encoder.layer.1.intermediate.dense.weight: grad min = -0.145986, grad max = 0.100363
# bert.encoder.layer.1.intermediate.dense.bias: grad min = -0.006253, grad max = 0.014131
# bert.encoder.layer.1.output.dense.weight: grad min = -0.017290, grad max = 0.013320
# bert.encoder.layer.1.output.dense.bias: grad min = -0.011865, grad max = 0.009983
# bert.encoder.layer.1.output.LayerNorm.weight: grad min = -0.010436, grad max = 0.054120
# bert.encoder.layer.1.output.LayerNorm.bias: grad min = -0.012470, grad max = 0.011835
# bert.encoder.layer.2.attention.self.query.weight: grad min = -0.009963, grad max = 0.012808
# bert.encoder.layer.2.attention.self.query.bias: grad min = -0.001365, grad max = 0.001099
# bert.encoder.layer.2.attention.self.key.weight: grad min = -0.005114, grad max = 0.007497
# bert.encoder.layer.2.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.2.attention.self.value.weight: grad min = -0.069000, grad max = 0.067601
# bert.encoder.layer.2.attention.self.value.bias: grad min = -0.008568, grad max = 0.007712
# bert.encoder.layer.2.attention.output.dense.weight: grad min = -0.016748, grad max = 0.014729
# bert.encoder.layer.2.attention.output.dense.bias: grad min = -0.014764, grad max = 0.012425
# bert.encoder.layer.2.attention.output.LayerNorm.weight: grad min = -0.011136, grad max = 0.013399
# bert.encoder.layer.2.attention.output.LayerNorm.bias: grad min = -0.012091, grad max = 0.010879
# bert.encoder.layer.2.intermediate.dense.weight: grad min = -0.173529, grad max = 0.115913
# bert.encoder.layer.2.intermediate.dense.bias: grad min = -0.008967, grad max = 0.013775
# bert.encoder.layer.2.output.dense.weight: grad min = -0.014818, grad max = 0.017392
# bert.encoder.layer.2.output.dense.bias: grad min = -0.012031, grad max = 0.011202
# bert.encoder.layer.2.output.LayerNorm.weight: grad min = -0.027645, grad max = 0.016244
# bert.encoder.layer.2.output.LayerNorm.bias: grad min = -0.016321, grad max = 0.014072
# bert.encoder.layer.3.attention.self.query.weight: grad min = -0.017106, grad max = 0.024307
# bert.encoder.layer.3.attention.self.query.bias: grad min = -0.004748, grad max = 0.003578
# bert.encoder.layer.3.attention.self.key.weight: grad min = -0.016354, grad max = 0.013192
# bert.encoder.layer.3.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.3.attention.self.value.weight: grad min = -0.089782, grad max = 0.075980
# bert.encoder.layer.3.attention.self.value.bias: grad min = -0.009718, grad max = 0.012271
# bert.encoder.layer.3.attention.output.dense.weight: grad min = -0.018303, grad max = 0.021777
# bert.encoder.layer.3.attention.output.dense.bias: grad min = -0.015729, grad max = 0.018588
# bert.encoder.layer.3.attention.output.LayerNorm.weight: grad min = -0.010411, grad max = 0.014032
# bert.encoder.layer.3.attention.output.LayerNorm.bias: grad min = -0.012552, grad max = 0.015309
# bert.encoder.layer.3.intermediate.dense.weight: grad min = -0.166166, grad max = 0.089188
# bert.encoder.layer.3.intermediate.dense.bias: grad min = -0.005498, grad max = 0.016810
# bert.encoder.layer.3.output.dense.weight: grad min = -0.014105, grad max = 0.013627
# bert.encoder.layer.3.output.dense.bias: grad min = -0.011582, grad max = 0.013347
# bert.encoder.layer.3.output.LayerNorm.weight: grad min = -0.028526, grad max = 0.044106
# bert.encoder.layer.3.output.LayerNorm.bias: grad min = -0.020042, grad max = 0.021816
# bert.encoder.layer.4.attention.self.query.weight: grad min = -0.010404, grad max = 0.012890
# bert.encoder.layer.4.attention.self.query.bias: grad min = -0.003683, grad max = 0.002166
# bert.encoder.layer.4.attention.self.key.weight: grad min = -0.023934, grad max = 0.029894
# bert.encoder.layer.4.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.4.attention.self.value.weight: grad min = -0.073443, grad max = 0.089056
# bert.encoder.layer.4.attention.self.value.bias: grad min = -0.012004, grad max = 0.010581
# bert.encoder.layer.4.attention.output.dense.weight: grad min = -0.010238, grad max = 0.011352
# bert.encoder.layer.4.attention.output.dense.bias: grad min = -0.015239, grad max = 0.014634
# bert.encoder.layer.4.attention.output.LayerNorm.weight: grad min = -0.011880, grad max = 0.013792
# bert.encoder.layer.4.attention.output.LayerNorm.bias: grad min = -0.014315, grad max = 0.014336
# bert.encoder.layer.4.intermediate.dense.weight: grad min = -0.163641, grad max = 0.112652
# bert.encoder.layer.4.intermediate.dense.bias: grad min = -0.007500, grad max = 0.013830
# bert.encoder.layer.4.output.dense.weight: grad min = -0.031056, grad max = 0.025224
# bert.encoder.layer.4.output.dense.bias: grad min = -0.015539, grad max = 0.011144
# bert.encoder.layer.4.output.LayerNorm.weight: grad min = -0.014487, grad max = 0.132386
# bert.encoder.layer.4.output.LayerNorm.bias: grad min = -0.022843, grad max = 0.018536
# bert.encoder.layer.5.attention.self.query.weight: grad min = -0.028703, grad max = 0.037224
# bert.encoder.layer.5.attention.self.query.bias: grad min = -0.004974, grad max = 0.003403
# bert.encoder.layer.5.attention.self.key.weight: grad min = -0.014381, grad max = 0.019089
# bert.encoder.layer.5.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.5.attention.self.value.weight: grad min = -0.097660, grad max = 0.090807
# bert.encoder.layer.5.attention.self.value.bias: grad min = -0.012327, grad max = 0.011003
# bert.encoder.layer.5.attention.output.dense.weight: grad min = -0.011837, grad max = 0.014375
# bert.encoder.layer.5.attention.output.dense.bias: grad min = -0.019265, grad max = 0.013859
# bert.encoder.layer.5.attention.output.LayerNorm.weight: grad min = -0.014181, grad max = 0.011463
# bert.encoder.layer.5.attention.output.LayerNorm.bias: grad min = -0.016424, grad max = 0.011793
# bert.encoder.layer.5.intermediate.dense.weight: grad min = -0.109345, grad max = 0.114994
# bert.encoder.layer.5.intermediate.dense.bias: grad min = -0.009042, grad max = 0.010661
# bert.encoder.layer.5.output.dense.weight: grad min = -0.019406, grad max = 0.023056
# bert.encoder.layer.5.output.dense.bias: grad min = -0.014218, grad max = 0.011933
# bert.encoder.layer.5.output.LayerNorm.weight: grad min = -0.087436, grad max = 0.014023
# bert.encoder.layer.5.output.LayerNorm.bias: grad min = -0.018768, grad max = 0.019873
# bert.encoder.layer.6.attention.self.query.weight: grad min = -0.031908, grad max = 0.029462
# bert.encoder.layer.6.attention.self.query.bias: grad min = -0.004996, grad max = 0.004866
# bert.encoder.layer.6.attention.self.key.weight: grad min = -0.048825, grad max = 0.041448
# bert.encoder.layer.6.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.6.attention.self.value.weight: grad min = -0.075504, grad max = 0.089039
# bert.encoder.layer.6.attention.self.value.bias: grad min = -0.011152, grad max = 0.013125
# bert.encoder.layer.6.attention.output.dense.weight: grad min = -0.010691, grad max = 0.009925
# bert.encoder.layer.6.attention.output.dense.bias: grad min = -0.015067, grad max = 0.013838
# bert.encoder.layer.6.attention.output.LayerNorm.weight: grad min = -0.013486, grad max = 0.012098
# bert.encoder.layer.6.attention.output.LayerNorm.bias: grad min = -0.015095, grad max = 0.014963
# bert.encoder.layer.6.intermediate.dense.weight: grad min = -0.154117, grad max = 0.134354
# bert.encoder.layer.6.intermediate.dense.bias: grad min = -0.007819, grad max = 0.017807
# bert.encoder.layer.6.output.dense.weight: grad min = -0.009166, grad max = 0.009698
# bert.encoder.layer.6.output.dense.bias: grad min = -0.010247, grad max = 0.011868
# bert.encoder.layer.6.output.LayerNorm.weight: grad min = -0.011674, grad max = 0.066214
# bert.encoder.layer.6.output.LayerNorm.bias: grad min = -0.013484, grad max = 0.020956
# bert.encoder.layer.7.attention.self.query.weight: grad min = -0.028378, grad max = 0.020388
# bert.encoder.layer.7.attention.self.query.bias: grad min = -0.002590, grad max = 0.003600
# bert.encoder.layer.7.attention.self.key.weight: grad min = -0.017921, grad max = 0.018421
# bert.encoder.layer.7.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.7.attention.self.value.weight: grad min = -0.060161, grad max = 0.070091
# bert.encoder.layer.7.attention.self.value.bias: grad min = -0.009432, grad max = 0.007540
# bert.encoder.layer.7.attention.output.dense.weight: grad min = -0.010621, grad max = 0.010006
# bert.encoder.layer.7.attention.output.dense.bias: grad min = -0.012098, grad max = 0.016079
# bert.encoder.layer.7.attention.output.LayerNorm.weight: grad min = -0.013503, grad max = 0.011978
# ...
# bert.encoder.layer.1.attention.output.dense.weight: grad min = -0.011947, grad max = 0.018729
# bert.encoder.layer.1.attention.output.dense.bias: grad min = -0.014356, grad max = 0.018932
# bert.encoder.layer.1.attention.output.LayerNorm.weight: grad min = -0.008167, grad max = 0.009767
# bert.encoder.layer.1.attention.output.LayerNorm.bias: grad min = -0.014672, grad max = 0.016033
# bert.encoder.layer.1.intermediate.dense.weight: grad min = -0.147782, grad max = 0.088184
# bert.encoder.layer.1.intermediate.dense.bias: grad min = -0.004749, grad max = 0.012505
# bert.encoder.layer.1.output.dense.weight: grad min = -0.012623, grad max = 0.012026
# bert.encoder.layer.1.output.dense.bias: grad min = -0.013438, grad max = 0.013271
# bert.encoder.layer.1.output.LayerNorm.weight: grad min = -0.181826, grad max = 0.007736
# bert.encoder.layer.1.output.LayerNorm.bias: grad min = -0.014462, grad max = 0.015904
# bert.encoder.layer.2.attention.self.query.weight: grad min = -0.017324, grad max = 0.026022
# bert.encoder.layer.2.attention.self.query.bias: grad min = -0.004343, grad max = 0.003021
# bert.encoder.layer.2.attention.self.key.weight: grad min = -0.017750, grad max = 0.016735
# bert.encoder.layer.2.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.2.attention.self.value.weight: grad min = -0.080794, grad max = 0.078928
# bert.encoder.layer.2.attention.self.value.bias: grad min = -0.011278, grad max = 0.012152
# bert.encoder.layer.2.attention.output.dense.weight: grad min = -0.016590, grad max = 0.018160
# bert.encoder.layer.2.attention.output.dense.bias: grad min = -0.013412, grad max = 0.014049
# bert.encoder.layer.2.attention.output.LayerNorm.weight: grad min = -0.007667, grad max = 0.008860
# bert.encoder.layer.2.attention.output.LayerNorm.bias: grad min = -0.014806, grad max = 0.014283
# bert.encoder.layer.2.intermediate.dense.weight: grad min = -0.116429, grad max = 0.108158
# bert.encoder.layer.2.intermediate.dense.bias: grad min = -0.006097, grad max = 0.005704
# bert.encoder.layer.2.output.dense.weight: grad min = -0.033418, grad max = 0.020444
# bert.encoder.layer.2.output.dense.bias: grad min = -0.012302, grad max = 0.014881
# bert.encoder.layer.2.output.LayerNorm.weight: grad min = -0.051024, grad max = 0.037883
# bert.encoder.layer.2.output.LayerNorm.bias: grad min = -0.014751, grad max = 0.019431
# bert.encoder.layer.3.attention.self.query.weight: grad min = -0.011200, grad max = 0.014958
# bert.encoder.layer.3.attention.self.query.bias: grad min = -0.002104, grad max = 0.001615
# bert.encoder.layer.3.attention.self.key.weight: grad min = -0.010277, grad max = 0.016010
# bert.encoder.layer.3.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.3.attention.self.value.weight: grad min = -0.097961, grad max = 0.119936
# bert.encoder.layer.3.attention.self.value.bias: grad min = -0.017821, grad max = 0.016379
# bert.encoder.layer.3.attention.output.dense.weight: grad min = -0.025577, grad max = 0.027142
# bert.encoder.layer.3.attention.output.dense.bias: grad min = -0.020640, grad max = 0.018845
# bert.encoder.layer.3.attention.output.LayerNorm.weight: grad min = -0.007760, grad max = 0.014688
# bert.encoder.layer.3.attention.output.LayerNorm.bias: grad min = -0.019470, grad max = 0.018554
# bert.encoder.layer.3.intermediate.dense.weight: grad min = -0.270131, grad max = 0.137968
# bert.encoder.layer.3.intermediate.dense.bias: grad min = -0.008527, grad max = 0.007507
# bert.encoder.layer.3.output.dense.weight: grad min = -0.016911, grad max = 0.010650
# bert.encoder.layer.3.output.dense.bias: grad min = -0.016414, grad max = 0.018066
# bert.encoder.layer.3.output.LayerNorm.weight: grad min = -0.011371, grad max = 0.053236
# bert.encoder.layer.3.output.LayerNorm.bias: grad min = -0.025108, grad max = 0.026084
# bert.encoder.layer.4.attention.self.query.weight: grad min = -0.040978, grad max = 0.017448
# bert.encoder.layer.4.attention.self.query.bias: grad min = -0.003304, grad max = 0.006719
# bert.encoder.layer.4.attention.self.key.weight: grad min = -0.032338, grad max = 0.013149
# bert.encoder.layer.4.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.4.attention.self.value.weight: grad min = -0.096305, grad max = 0.102921
# bert.encoder.layer.4.attention.self.value.bias: grad min = -0.017060, grad max = 0.017293
# bert.encoder.layer.4.attention.output.dense.weight: grad min = -0.012114, grad max = 0.014844
# bert.encoder.layer.4.attention.output.dense.bias: grad min = -0.019239, grad max = 0.019734
# bert.encoder.layer.4.attention.output.LayerNorm.weight: grad min = -0.010058, grad max = 0.015787
# bert.encoder.layer.4.attention.output.LayerNorm.bias: grad min = -0.018128, grad max = 0.018207
# bert.encoder.layer.4.intermediate.dense.weight: grad min = -0.081616, grad max = 0.141483
# bert.encoder.layer.4.intermediate.dense.bias: grad min = -0.005813, grad max = 0.005073
# bert.encoder.layer.4.output.dense.weight: grad min = -0.014577, grad max = 0.015725
# bert.encoder.layer.4.output.dense.bias: grad min = -0.019045, grad max = 0.021424
# bert.encoder.layer.4.output.LayerNorm.weight: grad min = -0.033946, grad max = 0.026490
# bert.encoder.layer.4.output.LayerNorm.bias: grad min = -0.028992, grad max = 0.025357
# bert.encoder.layer.5.attention.self.query.weight: grad min = -0.041182, grad max = 0.022730
# bert.encoder.layer.5.attention.self.query.bias: grad min = -0.003021, grad max = 0.004299
# bert.encoder.layer.5.attention.self.key.weight: grad min = -0.022002, grad max = 0.022358
# bert.encoder.layer.5.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.5.attention.self.value.weight: grad min = -0.097742, grad max = 0.143046
# bert.encoder.layer.5.attention.self.value.bias: grad min = -0.020457, grad max = 0.018137
# bert.encoder.layer.5.attention.output.dense.weight: grad min = -0.014414, grad max = 0.014318
# bert.encoder.layer.5.attention.output.dense.bias: grad min = -0.021549, grad max = 0.024958
# bert.encoder.layer.5.attention.output.LayerNorm.weight: grad min = -0.011018, grad max = 0.013720
# bert.encoder.layer.5.attention.output.LayerNorm.bias: grad min = -0.021632, grad max = 0.023404
# bert.encoder.layer.5.intermediate.dense.weight: grad min = -0.120313, grad max = 0.078978
# bert.encoder.layer.5.intermediate.dense.bias: grad min = -0.006209, grad max = 0.007639
# bert.encoder.layer.5.output.dense.weight: grad min = -0.020142, grad max = 0.021451
# bert.encoder.layer.5.output.dense.bias: grad min = -0.020324, grad max = 0.023762
# bert.encoder.layer.5.output.LayerNorm.weight: grad min = -0.182801, grad max = 0.015069
# bert.encoder.layer.5.output.LayerNorm.bias: grad min = -0.032026, grad max = 0.030548
# bert.encoder.layer.6.attention.self.query.weight: grad min = -0.065658, grad max = 0.078300
# bert.encoder.layer.6.attention.self.query.bias: grad min = -0.011042, grad max = 0.009291
# bert.encoder.layer.6.attention.self.key.weight: grad min = -0.084117, grad max = 0.051891
# bert.encoder.layer.6.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.6.attention.self.value.weight: grad min = -0.149483, grad max = 0.148240
# bert.encoder.layer.6.attention.self.value.bias: grad min = -0.020079, grad max = 0.022022
# bert.encoder.layer.6.attention.output.dense.weight: grad min = -0.013528, grad max = 0.015414
# bert.encoder.layer.6.attention.output.dense.bias: grad min = -0.024947, grad max = 0.026443
# bert.encoder.layer.6.attention.output.LayerNorm.weight: grad min = -0.020436, grad max = 0.013408
# bert.encoder.layer.6.attention.output.LayerNorm.bias: grad min = -0.024223, grad max = 0.025465
# bert.encoder.layer.6.intermediate.dense.weight: grad min = -0.151705, grad max = 0.157162
# bert.encoder.layer.6.intermediate.dense.bias: grad min = -0.019396, grad max = 0.012640
# bert.encoder.layer.6.output.dense.weight: grad min = -0.020061, grad max = 0.022418
# bert.encoder.layer.6.output.dense.bias: grad min = -0.021968, grad max = 0.026842
# bert.encoder.layer.6.output.LayerNorm.weight: grad min = -0.147568, grad max = 0.018456
# bert.encoder.layer.6.output.LayerNorm.bias: grad min = -0.027336, grad max = 0.041697
# bert.encoder.layer.7.attention.self.query.weight: grad min = -0.021116, grad max = 0.026301
# bert.encoder.layer.7.attention.self.query.bias: grad min = -0.004622, grad max = 0.004647
# bert.encoder.layer.7.attention.self.key.weight: grad min = -0.027911, grad max = 0.027247
# bert.encoder.layer.7.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.7.attention.self.value.weight: grad min = -0.130670, grad max = 0.127992
# bert.encoder.layer.7.attention.self.value.bias: grad min = -0.018052, grad max = 0.019015
# bert.encoder.layer.7.attention.output.dense.weight: grad min = -0.018051, grad max = 0.012868
# bert.encoder.layer.7.attention.output.dense.bias: grad min = -0.024245, grad max = 0.028669
# bert.encoder.layer.7.attention.output.LayerNorm.weight: grad min = -0.032973, grad max = 0.013399
# bert.encoder.layer.7.attention.output.LayerNorm.bias: grad min = -0.023240, grad max = 0.028550
# bert.encoder.layer.7.intermediate.dense.weight: grad min = -0.260724, grad max = 0.201553
# bert.encoder.layer.7.intermediate.dense.bias: grad min = -0.017044, grad max = 0.022856
# bert.encoder.layer.7.output.dense.weight: grad min = -0.015697, grad max = 0.016479
# bert.encoder.layer.7.output.dense.bias: grad min = -0.023284, grad max = 0.028147
# bert.encoder.layer.7.output.LayerNorm.weight: grad min = -0.103837, grad max = 0.016408
# bert.encoder.layer.7.output.LayerNorm.bias: grad min = -0.032669, grad max = 0.040954
# bert.encoder.layer.8.attention.self.query.weight: grad min = -0.047617, grad max = 0.047690
# bert.encoder.layer.8.attention.self.query.bias: grad min = -0.006598, grad max = 0.006659
# bert.encoder.layer.8.attention.self.key.weight: grad min = -0.024929, grad max = 0.018527
# bert.encoder.layer.8.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.8.attention.self.value.weight: grad min = -0.150487, grad max = 0.193109
# bert.encoder.layer.8.attention.self.value.bias: grad min = -0.035919, grad max = 0.029532
# bert.encoder.layer.8.attention.output.dense.weight: grad min = -0.017257, grad max = 0.019502
# bert.encoder.layer.8.attention.output.dense.bias: grad min = -0.025318, grad max = 0.024509
# bert.encoder.layer.8.attention.output.LayerNorm.weight: grad min = -0.022403, grad max = 0.016953
# bert.encoder.layer.8.attention.output.LayerNorm.bias: grad min = -0.024519, grad max = 0.020348
# bert.encoder.layer.8.intermediate.dense.weight: grad min = -0.378066, grad max = 0.525585
# bert.encoder.layer.8.intermediate.dense.bias: grad min = -0.033260, grad max = 0.023926
# bert.encoder.layer.8.output.dense.weight: grad min = -0.020305, grad max = 0.021296
# bert.encoder.layer.8.output.dense.bias: grad min = -0.021870, grad max = 0.018365
# bert.encoder.layer.8.output.LayerNorm.weight: grad min = -0.020198, grad max = 0.241201
# bert.encoder.layer.8.output.LayerNorm.bias: grad min = -0.032501, grad max = 0.029461
# bert.encoder.layer.9.attention.self.query.weight: grad min = -0.068280, grad max = 0.043211
# bert.encoder.layer.9.attention.self.query.bias: grad min = -0.007551, grad max = 0.011501
# bert.encoder.layer.9.attention.self.key.weight: grad min = -0.024230, grad max = 0.034019
# bert.encoder.layer.9.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.9.attention.self.value.weight: grad min = -0.076242, grad max = 0.096346
# bert.encoder.layer.9.attention.self.value.bias: grad min = -0.025057, grad max = 0.020421
# bert.encoder.layer.9.attention.output.dense.weight: grad min = -0.013983, grad max = 0.013711
# bert.encoder.layer.9.attention.output.dense.bias: grad min = -0.012167, grad max = 0.012979
# bert.encoder.layer.9.attention.output.LayerNorm.weight: grad min = -0.030009, grad max = 0.007664
# bert.encoder.layer.9.attention.output.LayerNorm.bias: grad min = -0.011720, grad max = 0.011810
# bert.encoder.layer.9.intermediate.dense.weight: grad min = -0.120778, grad max = 0.302689
# bert.encoder.layer.9.intermediate.dense.bias: grad min = -0.023614, grad max = 0.011635
# bert.encoder.layer.9.output.dense.weight: grad min = -0.013363, grad max = 0.012214
# bert.encoder.layer.9.output.dense.bias: grad min = -0.011278, grad max = 0.010102
# bert.encoder.layer.9.output.LayerNorm.weight: grad min = -0.011235, grad max = 0.046865
# bert.encoder.layer.9.output.LayerNorm.bias: grad min = -0.017775, grad max = 0.016233
# bert.encoder.layer.10.attention.self.query.weight: grad min = -0.032589, grad max = 0.037899
# bert.encoder.layer.10.attention.self.query.bias: grad min = -0.004910, grad max = 0.004139
# bert.encoder.layer.10.attention.self.key.weight: grad min = -0.011202, grad max = 0.009514
# bert.encoder.layer.10.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.10.attention.self.value.weight: grad min = -0.081848, grad max = 0.059159
# bert.encoder.layer.10.attention.self.value.bias: grad min = -0.014999, grad max = 0.017851
# bert.encoder.layer.10.attention.output.dense.weight: grad min = -0.008612, grad max = 0.007633
# bert.encoder.layer.10.attention.output.dense.bias: grad min = -0.008686, grad max = 0.007533
# bert.encoder.layer.10.attention.output.LayerNorm.weight: grad min = -0.035432, grad max = 0.005776
# bert.encoder.layer.10.attention.output.LayerNorm.bias: grad min = -0.007814, grad max = 0.007211
# bert.encoder.layer.10.intermediate.dense.weight: grad min = -0.174606, grad max = 0.106176
# bert.encoder.layer.10.intermediate.dense.bias: grad min = -0.008729, grad max = 0.013841
# bert.encoder.layer.10.output.dense.weight: grad min = -0.012853, grad max = 0.017453
# bert.encoder.layer.10.output.dense.bias: grad min = -0.007387, grad max = 0.006466
# bert.encoder.layer.10.output.LayerNorm.weight: grad min = -0.013373, grad max = 0.010687
# bert.encoder.layer.10.output.LayerNorm.bias: grad min = -0.010759, grad max = 0.009602
# bert.encoder.layer.11.attention.self.query.weight: grad min = -0.034860, grad max = 0.043850
# bert.encoder.layer.11.attention.self.query.bias: grad min = -0.004939, grad max = 0.003835
# bert.encoder.layer.11.attention.self.key.weight: grad min = -0.012488, grad max = 0.012102
# bert.encoder.layer.11.attention.self.key.bias: grad min = -0.000000, grad max = 0.000000
# bert.encoder.layer.11.attention.self.value.weight: grad min = -0.089108, grad max = 0.135549
# bert.encoder.layer.11.attention.self.value.bias: grad min = -0.015934, grad max = 0.010390
# bert.encoder.layer.11.attention.output.dense.weight: grad min = -0.005592, grad max = 0.004673
# bert.encoder.layer.11.attention.output.dense.bias: grad min = -0.004019, grad max = 0.003007
# bert.encoder.layer.11.attention.output.LayerNorm.weight: grad min = -0.015443, grad max = 0.002719
# bert.encoder.layer.11.attention.output.LayerNorm.bias: grad min = -0.002929, grad max = 0.002526
# bert.encoder.layer.11.intermediate.dense.weight: grad min = -0.070412, grad max = 0.039409
# bert.encoder.layer.11.intermediate.dense.bias: grad min = -0.001990, grad max = 0.002860
# bert.encoder.layer.11.output.dense.weight: grad min = -0.002647, grad max = 0.002411
# bert.encoder.layer.11.output.dense.bias: grad min = -0.002570, grad max = 0.002169
# bert.encoder.layer.11.output.LayerNorm.weight: grad min = -0.007894, grad max = 0.003610
# bert.encoder.layer.11.output.LayerNorm.bias: grad min = -0.004502, grad max = 0.003866
# bert.pooler.dense.weight: grad min = -0.025538, grad max = 0.025570
# bert.pooler.dense.bias: grad min = -0.004980, grad max = 0.005061
# classifier.weight: grad min = -0.103359, grad max = 0.097985
# classifier.bias: grad min = 0.091360, grad max = 0.091360
# Epoch 2 Loss: 0.1788
#
#  F1 Score: 0.904
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.92      0.88      1125
#          1.0       0.93      0.88      0.90      1500
#
#     accuracy                           0.89      2625
#    macro avg       0.89      0.90      0.89      2625
# weighted avg       0.90      0.89      0.89      2625

# %%
def predict_sentiment(text, model, tokenizer, max_length=256):
    model.eval()

    #text = speller(text)
    text = preprocess_text(text)
    #text = preprocess_text1(text)
    #text = extract_context_window(text, window=2)
    #print(text)

    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding="max_length", max_length=max_length)
    input_ids = inputs['input_ids'].to(device)
    attention_mask = inputs['attention_mask'].to(device)

    with torch.no_grad():
        logits = model(input_ids, attention_mask)
        prob = torch.sigmoid(logits).item()

    #prob = adjust_prediction_with_negation(text, prob, flip_threshold=0.7)
    label = 1 if prob >= 0.51 else 0
    print(f"\n📝 Review: {text}")
    print(f"🔢 Predicted Sentiment: {label} (Confidence: {prob:.4f})")

    return label, prob
test_review = "this game ois so bad becuase the price and the graphics , paid for nothing"
predict_sentiment(test_review, model, tokenizer)
# Out:
# 📝 Review: this game ois so bad becuase the price and the graphics , paid for nothing
# 🔢 Predicted Sentiment: 0 (Confidence: 0.0061)
# (0, 0.006145811174064875)

# %%
# Out:
#   Cell In[17], line 1
#     return label, prob
#     ^
# SyntaxError: 'return' outside function

# %%
# torch.save(model.state_dict(), "Sentiment_Overall_Model.pt")
# print("✅ Model state saved to: Sentiment_Overall_Model.pt")
# Out:
# ✅ Model state saved to: Sentiment_Overall_Model.pt

# %%
model = BertBinaryMultiLabelClassifier(num_labels=1)
model.load_state_dict(torch.load("C:/Users/ASUS/Desktop/University/second semester 2025 (END)/Capstone2/Sentiment_Overall_Model.pt", map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
model.to(device)
model.eval()
print("✅ Gameplay Sentiment Overall Model loaded...")
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_21072\1694394684.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("C:/Users/ASUS/Desktop/University/second semester 2025 (END)/Capstone2/Sentiment_Overall_Model.pt", map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
# ✅ Gameplay Sentiment Overall Model loaded...

# %% [markdown]
# ### Sentiment Classes Model

# %%
df = pd.read_csv("/content/train.csv")
X = df["user_review"]
y = df["user_suggestion"].tolist()

# %%
X = X.apply(preprocess_text)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.15, random_state=0)

train_encodings = tokenizer(X_train.tolist(), truncation=True, padding="max_length", max_length=256, return_tensors="pt")
val_encodings = tokenizer(X_val.tolist(), truncation=True, padding="max_length", max_length=256, return_tensors="pt")

train_dataset = TensorDataset(train_encodings['input_ids'],train_encodings['attention_mask'],torch.tensor(y_train).float().view(-1, 1))
val_dataset = TensorDataset(val_encodings['input_ids'],val_encodings['attention_mask'],torch.tensor(y_val).float().view(-1, 1))

train_loader = DataLoader(train_dataset, sampler=RandomSampler(train_dataset), batch_size=32)
val_loader = DataLoader(val_dataset, sampler=SequentialSampler(val_dataset), batch_size=32)

model = BertBinaryMultiLabelClassifier(num_labels=1).to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=2e-5)
loss_fn = nn.BCEWithLogitsLoss()

#clip_value = 50.0
epochs = 2
for epoch in range(epochs):
    model.train()
    total_loss = 0
    for step, batch in enumerate(train_loader):
        b_input_ids, b_input_mask, b_labels = [b.to(device) for b in batch]
        model.zero_grad()
        logits = model(b_input_ids, b_input_mask)
        loss = loss_fn(logits, b_labels.float())
        loss.backward()

        if step % 50 == 0:
            print(f"\n--- Gradient Report at Step {step}, Epoch {epoch+1} ---")
            for name, param in model.named_parameters():
                if param.requires_grad and param.grad is not None:
                    print(f"{name}: grad min = {param.grad.min():.6f}, grad max = {param.grad.max():.6f}")

        #clip_grad_norm_(model.parameters(), clip_value)
        optimizer.step()
        total_loss += loss.item()

    print(f"Epoch {epoch+1} Loss: {total_loss / len(train_loader):.4f}")

model.eval()
predictions, true_labels = [], []

with torch.no_grad():
    for batch in val_loader:
        b_input_ids, b_input_mask, b_labels = [b.to(device) for b in batch]
        logits = model(b_input_ids, b_input_mask)
        probs = torch.sigmoid(logits).cpu().numpy()
        predictions.extend(probs)
        true_labels.extend(b_labels.cpu().numpy())

pred_array = np.array(predictions)
pred_labels = (pred_array >= 0.5).astype(int)
true_labels = np.array(true_labels)

f1 = f1_score(true_labels, pred_labels)
print("\n F1 Score:", round(f1, 4))
print("\nClassification Report:")
print(classification_report(true_labels, pred_labels))

# %%
gameplay_keywords = [
    "gameplay", "controls", "movement", "mechanics", "combat", "shooting", "driving",
    "jumping", "pacing", "balance", "physics", "interaction", "difficulty", "ai", 'playstyle',
    'play style', 'technique', 'techniques', 'cpu', 'play', 'difficult', "attack", "attack", "system",

]

visual_keywords = {
    "graphic", "graphics", "art", "drawing", "drawings", "style",
    "animation", "visual", "visuals","design", "texture", "render",
    "appearance", "resolution", "resolutions","color", "environment"
}

story_keywords = {
    "story", "storyline", "plot", "narrative", "writing", "dialogue", "script",
    "cutscene", "cutscenes", "character", "characters", "backstory",
    "development", "lore", "quest", "quests", "theme", "themes",
    "protagonist", "antagonist", "emotion", "emotional", "twist", "ending",
    "arc", "worldbuilding", "immersive", "immersion", "journey", "setting",
    "endings", "end", "narrator", "arcs"
}

pricing_keywords = {
    "price", "priced", "pricing", "cheap", "expensive", "cost", "costs", "value", "worth",
    "deal", "deals", "sale", "sales", "discount", "discounted", "money", "pay", "paid",
    "purchase", "purchased", "buy", "bought", "refund", "refunded", "dlc", "microtransaction",
    "microtransactions", "transaction", "transactions", "season pass", "loot box", "loot boxes",
    "in-game purchase", "in-game purchases", "in game", "add-on", "add-ons", "add on", "add ons","affordable", "overpriced", "underpriced",
    "wallet", "wallet-friendly", "pricing model", "price tag", "not worth", "worth it", "ripoff",
    "overcharge", "reasonable", "expensive", "free", "free-to-play", "freemium", "premium", "addons"
}

bug_keywords = {
    "bug", "bugs", "glitch", "glitches", "crash", "crashes", "crashed", "crashing",
    "lag", "laggy", "freeze", "freezes", "freezing", "stutter", "stuttering",
    "frame drop", "frame rate", "fps drop", "low fps", "optimization", "unoptimized",
    "unstable", "desync", "broken", "gamebreaking", "game-breaking", "issue", "issues",
    "problem", "problems", "technical", "update broke", "patched", "patch broke",
    "unplayable", "error", "errors", "connection issue", "server lag", "network lag",
    "buggy", "glitchy", "softlock", "hardlock", "lag spikes", "performance", "load times",
    "loading bug", "input lag", "jank", "debug", "runtime error", "black screen",
    "infinite loading", "flickering", "corrupt save", "save bug", "fix client", "client",
    "stuck", "stick"
}

# %%
def extract_context_window(text, window=4):
    words = re.findall(r"\w+", str(text).lower())
    
    indices = [i for i, word in enumerate(words) if word in visual_keywords]
    if not indices:
        return ""
    i = indices[0]
    start = max(0, i - window)
    end = min(len(words), i + window + 1)
    return " ".join(words[start:end])


def predict_sentiment(text, model, tokenizer, max_length=256):
    model.eval()

    text = speller(text)
    text = preprocess_text(text)
    text = preprocess_text1(text)
    text = extract_context_window(text, window=2)
    #print(text)

    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding="max_length", max_length=max_length)
    input_ids = inputs['input_ids'].to(device)
    attention_mask = inputs['attention_mask'].to(device)

    with torch.no_grad():
        logits = model(input_ids, attention_mask)
        prob = torch.sigmoid(logits).item()

    #prob = adjust_prediction_with_negation(text, prob, flip_threshold=0.7)
    label = 1 if prob >= 0.51 else 0
    print(f"\n📝 Review: {text}")
    print(f"🔢 Predicted Sentiment: {label} (Confidence: {prob:.4f})")

    return label, prob
test_review = "this game ois so bad becuase the price and the graphics , paid for nothing"
predict_sentiment(test_review, model, tokenizer)
# Out:
# 📝 Review: bad price graphics pay nothing
# 🔢 Predicted Sentiment: 0 (Confidence: 0.0588)
# (0, 0.05880578234791756)

# %%
# torch.save(model.state_dict(), "Sentiment_Classes_Model_Final.pt")
# print("✅ Model state saved to: Sentiment_Classes_Model_Final.pt")

# %%
model = BertBinaryMultiLabelClassifier(num_labels=1)
model.load_state_dict(torch.load("C:/Users/ASUS/Desktop/University/second semester 2025 (END)/Capstone2/Sentiment_Overall_Model.pt", map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
model.to(device)
model.eval()
print("✅ Gameplay Sentiment Classes Model loaded...")
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_21072\4269844664.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("C:/Users/ASUS/Desktop/University/second semester 2025 (END)/Capstone2/Sentiment_Overall_Model.pt", map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
# ✅ Gameplay Sentiment Classes Model loaded...

# %%
def extract_context_window(text, window=4):
    words = re.findall(r"\w+", str(text).lower())
    all_keywords = set(gameplay_keywords) | visual_keywords | story_keywords | pricing_keywords | bug_keywords
    indices = [i for i, word in enumerate(words) if word in all_keywords]
    if not indices:
        return ""
    i = indices[0]
    start = max(0, i - window)
    end = min(len(words), i + window + 1)
    return " ".join(words[start:end])

def get_matched_keywords(text, keyword_set):
    words = re.findall(r"\w+", text.lower())
    return list(set(words) & keyword_set)

def predict_sentiment(text, model, tokenizer, max_length=256):
    model.eval()

    original_text = text  # Save the original for keyword extraction
    text = speller(text)
    text = preprocess_text(text)
    text = preprocess_text1(text)
    text = extract_context_window(text, window=2)

    # Extract matched keywords for explainability
    matched_keywords = get_matched_keywords(original_text, pricing_keywords.union(visual_keywords, story_keywords, gameplay_keywords, bug_keywords))

    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding="max_length", max_length=max_length)
    input_ids = inputs['input_ids'].to(device)
    attention_mask = inputs['attention_mask'].to(device)

    with torch.no_grad():
        logits = model(input_ids, attention_mask)
        prob = torch.sigmoid(logits).item()

    label = 1 if prob >= 0.51 else 0
    sentiment_text = "positive" if label == 1 else "negative"

    print(f"\n📝 Review: {text}")
    print(f"🔍 Detected Keywords: {matched_keywords}")
    print(f"🔢 Predicted Sentiment: {label} (Confidence: {prob:.4f})")

    if matched_keywords:
        reasons = ", ".join(matched_keywords)
        print(f"🗯️ The game review is {sentiment_text}, likely due to: {reasons}.")
    else:
        print(f"🗯️ The game review is {sentiment_text}.")

    return label, prob, matched_keywords

# %%
test_review = "This game will reward you with a high trust factor even after thousands of hours spent queueing with friends and playing fair — so now you'll enjoy matches with equally fair, skilled, and communicative teammates as a reward for your dedication. The best part is how smooth and consistent the experience feels, even when things get tense. If you can appreciate occasional bugs or quirks without letting them ruin the fun: absolutely give it a try. As a game, it's brilliantly crafted and incredibly addictive. While no system is perfect (some minor matchmaking inconsistencies or rare bugs), it still earns my full recommendation — both for casual players and competitive enthusiasts."
predict_sentiment(test_review, model, tokenizer)
# Out:
# 📝 Review: queue friends play fair enjoy
# 🔍 Detected Keywords: ['bugs', 'system']
# 🔢 Predicted Sentiment: 1 (Confidence: 0.9795)
# 🗯️ The game review is positive, likely due to: bugs, system.
# (1, 0.9794834852218628, ['bugs', 'system'])
